# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
## This is the initial imported code from 
## the Cartpole zipped file
## The Solved is in 26 runs, with 126 total runs.
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.995, score: 21
# Scores: (min: 21, avg: 21, max: 21)
#
# Run: 2, exploration: 0.9137248860125932, score: 18
# Scores: (min: 18, avg: 19.5, max: 21)
#
# Run: 3, exploration: 0.7590483508202912, score: 38
# Scores: (min: 18, avg: 25.666666666666668, max: 38)
#
# Run: 4, exploration: 0.7219385759785162, score: 11
# Scores: (min: 11, avg: 22, max: 38)
#
# Run: 5, exploration: 0.6763948591909945, score: 14
# Scores: (min: 11, avg: 20.4, max: 38)
#
# Run: 6, exploration: 0.5848838636585911, score: 30
# Scores: (min: 11, avg: 22, max: 38)
#
# Run: 7, exploration: 0.5562889678716474, score: 11
# Scores: (min: 11, avg: 20.428571428571427, max: 38)
#
# Run: 8, exploration: 0.5211953074858876, score: 14
# Scores: (min: 11, avg: 19.625, max: 38)
#
# Run: 9, exploration: 0.49571413690105054, score: 11
# Scores: (min: 11, avg: 18.666666666666668, max: 38)
#
# Run: 10, exploration: 0.47147873742168567, score: 11
# Scores: (min: 11, avg: 17.9, max: 38)
#
# Run: 11, exploration: 0.43952667968844233, score: 15
# Scores: (min: 11, avg: 17.636363636363637, max: 38)
#
# Run: 12, exploration: 0.40565285250151817, score: 17
# Scores: (min: 11, avg: 17.583333333333332, max: 38)
#
# Run: 13, exploration: 0.37251769488706843, score: 18
# Scores: (min: 11, avg: 17.615384615384617, max: 38)
#
# Run: 14, exploration: 0.3578751580867638, score: 9
# Scores: (min: 9, avg: 17, max: 38)
#
# Run: 15, exploration: 0.17829525136613786, score: 140
# Scores: (min: 9, avg: 25.2, max: 140)
#
# Run: 16, exploration: 0.1176130407830293, score: 84
# Scores: (min: 9, avg: 28.875, max: 140)
#
# Run: 17, exploration: 0.09017346495423652, score: 54
# Scores: (min: 9, avg: 30.352941176470587, max: 140)
#
# Run: 18, exploration: 0.07232597730414898, score: 45
# Scores: (min: 9, avg: 31.166666666666668, max: 140)
#
# Run: 19, exploration: 0.045605554379880814, score: 93
# Scores: (min: 9, avg: 34.421052631578945, max: 140)
#
# Run: 20, exploration: 0.019844910434467605, score: 167
# Scores: (min: 9, avg: 41.05, max: 167)
#
# Run: 21, exploration: 0.01302530572838545, score: 85
# Scores: (min: 9, avg: 43.142857142857146, max: 167)
#
# Run: 22, exploration: 0.01, score: 70
# Scores: (min: 9, avg: 44.36363636363637, max: 167)
#
# Run: 23, exploration: 0.01, score: 74
# Scores: (min: 9, avg: 45.65217391304348, max: 167)
#
# Run: 24, exploration: 0.01, score: 67
# Scores: (min: 9, avg: 46.541666666666664, max: 167)
#
# Run: 25, exploration: 0.01, score: 75
# Scores: (min: 9, avg: 47.68, max: 167)
#
# Run: 26, exploration: 0.01, score: 84
# Scores: (min: 9, avg: 49.07692307692308, max: 167)
#
# Run: 27, exploration: 0.01, score: 77
# Scores: (min: 9, avg: 50.111111111111114, max: 167)
#
# Run: 28, exploration: 0.01, score: 75
# Scores: (min: 9, avg: 51, max: 167)
#
# Run: 29, exploration: 0.01, score: 218
# Scores: (min: 9, avg: 56.758620689655174, max: 218)
#
# Run: 30, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 58.4, max: 218)
#
# Run: 31, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 60.096774193548384, max: 218)
#
# Run: 32, exploration: 0.01, score: 248
# Scores: (min: 9, avg: 65.96875, max: 248)
#
# Run: 33, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 67.33333333333333, max: 248)
#
# Run: 34, exploration: 0.01, score: 189
# Scores: (min: 9, avg: 70.91176470588235, max: 248)
#
# Run: 35, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 73.65714285714286, max: 248)
#
# Run: 36, exploration: 0.01, score: 276
# Scores: (min: 9, avg: 79.27777777777777, max: 276)
#
# Run: 37, exploration: 0.01, score: 358
# Scores: (min: 9, avg: 86.8108108108108, max: 358)
#
# Run: 38, exploration: 0.01, score: 325
# Scores: (min: 9, avg: 93.07894736842105, max: 358)
#
# Run: 39, exploration: 0.01, score: 320
# Scores: (min: 9, avg: 98.8974358974359, max: 358)
#
# Run: 40, exploration: 0.01, score: 229
# Scores: (min: 9, avg: 102.15, max: 358)
#
# Run: 41, exploration: 0.01, score: 197
# Scores: (min: 9, avg: 104.46341463414635, max: 358)
#
# Run: 42, exploration: 0.01, score: 219
# Scores: (min: 9, avg: 107.19047619047619, max: 358)
#
# Run: 43, exploration: 0.01, score: 226
# Scores: (min: 9, avg: 109.95348837209302, max: 358)
#
# Run: 44, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 111.61363636363636, max: 358)
#
# Run: 45, exploration: 0.01, score: 184
# Scores: (min: 9, avg: 113.22222222222223, max: 358)
#
# Run: 46, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 114.17391304347827, max: 358)
#
# Run: 47, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 115.38297872340425, max: 358)
#
# Run: 48, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 117.04166666666667, max: 358)
#
# Run: 49, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 117.75510204081633, max: 358)
#
# Run: 50, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 118.24, max: 358)
#
# Run: 51, exploration: 0.01, score: 189
# Scores: (min: 9, avg: 119.62745098039215, max: 358)
#
# Run: 52, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 120.38461538461539, max: 358)
#
# Run: 53, exploration: 0.01, score: 150
# Scores: (min: 9, avg: 120.94339622641509, max: 358)
#
# Run: 54, exploration: 0.01, score: 196
# Scores: (min: 9, avg: 122.33333333333333, max: 358)
#
# Run: 55, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 123.38181818181818, max: 358)
#
# Run: 56, exploration: 0.01, score: 200
# Scores: (min: 9, avg: 124.75, max: 358)
#
# Run: 57, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 125.21052631578948, max: 358)
#
# Run: 58, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 126.03448275862068, max: 358)
#
# Run: 59, exploration: 0.01, score: 165
# Scores: (min: 9, avg: 126.69491525423729, max: 358)
#
# Run: 60, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 127.35, max: 358)
#
# Run: 61, exploration: 0.01, score: 376
# Scores: (min: 9, avg: 131.4262295081967, max: 376)
#
# Run: 62, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 132, max: 376)
#
# Run: 63, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 131.984126984127, max: 376)
#
# Run: 64, exploration: 0.01, score: 169
# Scores: (min: 9, avg: 132.5625, max: 376)
#
# Run: 65, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 132.58461538461538, max: 376)
#
# Run: 66, exploration: 0.01, score: 262
# Scores: (min: 9, avg: 134.54545454545453, max: 376)
#
# Run: 67, exploration: 0.01, score: 205
# Scores: (min: 9, avg: 135.59701492537314, max: 376)
#
# Run: 68, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 135.5735294117647, max: 376)
#
# Run: 69, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 135.57971014492753, max: 376)
#
# Run: 70, exploration: 0.01, score: 278
# Scores: (min: 9, avg: 137.61428571428573, max: 376)
#
# Run: 71, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 137.80281690140845, max: 376)
#
# Run: 72, exploration: 0.01, score: 230
# Scores: (min: 9, avg: 139.08333333333334, max: 376)
#
# Run: 73, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 139.57534246575344, max: 376)
#
# Run: 74, exploration: 0.01, score: 359
# Scores: (min: 9, avg: 142.54054054054055, max: 376)
#
# Run: 75, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 142.62666666666667, max: 376)
#
# Run: 76, exploration: 0.01, score: 220
# Scores: (min: 9, avg: 143.64473684210526, max: 376)
#
# Run: 77, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 144.84415584415584, max: 376)
#
# Run: 78, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 144.82051282051282, max: 376)
#
# Run: 79, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 144.67088607594937, max: 376)
#
# Run: 80, exploration: 0.01, score: 120
# Scores: (min: 9, avg: 144.3625, max: 376)
#
# Run: 81, exploration: 0.01, score: 271
# Scores: (min: 9, avg: 145.92592592592592, max: 376)
#
# Run: 82, exploration: 0.01, score: 239
# Scores: (min: 9, avg: 147.0609756097561, max: 376)
#
# Run: 83, exploration: 0.01, score: 329
# Scores: (min: 9, avg: 149.25301204819277, max: 376)
#
# Run: 84, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 149.0952380952381, max: 376)
#
# Run: 85, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 149.2, max: 376)
#
# Run: 86, exploration: 0.01, score: 221
# Scores: (min: 9, avg: 150.03488372093022, max: 376)
#
# Run: 87, exploration: 0.01, score: 176
# Scores: (min: 9, avg: 150.33333333333334, max: 376)
#
# Run: 88, exploration: 0.01, score: 255
# Scores: (min: 9, avg: 151.52272727272728, max: 376)
#
# Run: 89, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 151.6067415730337, max: 376)
#
# Run: 90, exploration: 0.01, score: 200
# Scores: (min: 9, avg: 152.14444444444445, max: 376)
# Run: 91, exploration: 0.01, score: 122
# Scores: (min: 9, avg: 151.8131868131868, max: 376)
#
# Run: 92, exploration: 0.01, score: 212
# Scores: (min: 9, avg: 152.4673913043478, max: 376)
#
# Run: 93, exploration: 0.01, score: 191
# Scores: (min: 9, avg: 152.88172043010752, max: 376)
#
# Run: 94, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 153.7659574468085, max: 376)
#
# Run: 95, exploration: 0.01, score: 248
# Scores: (min: 9, avg: 154.7578947368421, max: 376)
#
# Run: 96, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 154.77083333333334, max: 376)
#
# Run: 97, exploration: 0.01, score: 222
# Scores: (min: 9, avg: 155.46391752577318, max: 376)
#
# Run: 98, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 154.9591836734694, max: 376)
#
# Run: 99, exploration: 0.01, score: 115
# Scores: (min: 9, avg: 154.55555555555554, max: 376)
#
# Run: 100, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 154.18, max: 376)
#
# Run: 101, exploration: 0.01, score: 189
# Scores: (min: 9, avg: 155.86, max: 376)
#
# Run: 102, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 156.73, max: 376)
#
# Run: 103, exploration: 0.01, score: 207
# Scores: (min: 9, avg: 158.42, max: 376)
#
# Run: 104, exploration: 0.01, score: 251
# Scores: (min: 9, avg: 160.82, max: 376)
#
# Run: 105, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 161.85, max: 376)
#
# Run: 106, exploration: 0.01, score: 215
# Scores: (min: 9, avg: 163.7, max: 376)
#
# Run: 107, exploration: 0.01, score: 188
# Scores: (min: 9, avg: 165.47, max: 376)
#
# Run: 108, exploration: 0.01, score: 247
# Scores: (min: 9, avg: 167.8, max: 376)
#
# Run: 109, exploration: 0.01, score: 298
# Scores: (min: 9, avg: 170.67, max: 376)
#
# Run: 110, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 172.08, max: 376)
#
# Run: 111, exploration: 0.01, score: 112
# Scores: (min: 9, avg: 173.05, max: 376)
#
# Run: 112, exploration: 0.01, score: 353
# Scores: (min: 9, avg: 176.41, max: 376)
#
# Run: 113, exploration: 0.01, score: 233
# Scores: (min: 9, avg: 178.56, max: 376)
#
# Run: 114, exploration: 0.01, score: 180
# Scores: (min: 45, avg: 180.27, max: 376)
#
# Run: 115, exploration: 0.01, score: 170
# Scores: (min: 45, avg: 180.57, max: 376)
#
# Run: 116, exploration: 0.01, score: 237
# Scores: (min: 45, avg: 182.1, max: 376)
#
# Run: 117, exploration: 0.01, score: 127
# Scores: (min: 45, avg: 182.83, max: 376)
#
# Run: 118, exploration: 0.01, score: 408
# Scores: (min: 67, avg: 186.46, max: 408)
#
# Run: 119, exploration: 0.01, score: 252
# Scores: (min: 67, avg: 188.05, max: 408)
#
# Run: 120, exploration: 0.01, score: 284
# Scores: (min: 67, avg: 189.22, max: 408)
#
# Run: 121, exploration: 0.01, score: 300
# Scores: (min: 67, avg: 191.37, max: 408)
#
# Run: 122, exploration: 0.01, score: 144
# Scores: (min: 67, avg: 192.11, max: 408)
#
# Run: 123, exploration: 0.01, score: 134
# Scores: (min: 67, avg: 192.71, max: 408)
#
# Run: 124, exploration: 0.01, score: 219
# Scores: (min: 75, avg: 194.23, max: 408)
#
# Run: 125, exploration: 0.01, score: 18
# Scores: (min: 18, avg: 193.66, max: 408)
#
# Run: 126, exploration: 0.01, score: 404
# Scores: (min: 18, avg: 196.86, max: 408)
#
# Solved in 26 runs, 126 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-7c314f33fc7a> in cartpole()
#      87             if terminal:
#      88                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 89                 score_logger.add_score(step, run)
#      90                 break
#      91             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
## First Modification

## I modified the Exploration factors, including the 
## Exploration_Max (0.98), exploration_Min (0.15), and the exploration_Decay (0.970) 
## Solved in 30 runs, 130 total runs.

import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  

from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 0.98  
EXPLORATION_MIN = 0.15  
EXPLORATION_DECAY = 0.970  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.4176713010652507, score: 48
# Scores: (min: 48, avg: 48, max: 48)
#
# Run: 2, exploration: 0.30800089451711105, score: 11
# Scores: (min: 11, avg: 29.5, max: 48)
#
# Run: 3, exploration: 0.22712729072213747, score: 11
# Scores: (min: 11, avg: 23.333333333333332, max: 48)
#
# Run: 4, exploration: 0.16748914405478274, score: 11
# Scores: (min: 11, avg: 20.25, max: 48)
#
# Run: 5, exploration: 0.15, score: 16
# Scores: (min: 11, avg: 19.4, max: 48)
#
# Run: 6, exploration: 0.15, score: 10
# Scores: (min: 10, avg: 17.833333333333332, max: 48)
#
# Run: 7, exploration: 0.15, score: 9
# Scores: (min: 9, avg: 16.571428571428573, max: 48)
#
# Run: 8, exploration: 0.15, score: 11
# Scores: (min: 9, avg: 15.875, max: 48)
#
# Run: 9, exploration: 0.15, score: 11
# Scores: (min: 9, avg: 15.333333333333334, max: 48)
#
# Run: 10, exploration: 0.15, score: 17
# Scores: (min: 9, avg: 15.5, max: 48)
#
# Run: 11, exploration: 0.15, score: 13
# Scores: (min: 9, avg: 15.272727272727273, max: 48)
#
# Run: 12, exploration: 0.15, score: 10
# Scores: (min: 9, avg: 14.833333333333334, max: 48)
#
# Run: 13, exploration: 0.15, score: 9
# Scores: (min: 9, avg: 14.384615384615385, max: 48)
#
# Run: 14, exploration: 0.15, score: 8
# Scores: (min: 8, avg: 13.928571428571429, max: 48)
#
# Run: 15, exploration: 0.15, score: 12
# Scores: (min: 8, avg: 13.8, max: 48)
#
# Run: 16, exploration: 0.15, score: 10
# Scores: (min: 8, avg: 13.5625, max: 48)
#
# Run: 17, exploration: 0.15, score: 10
# Scores: (min: 8, avg: 13.352941176470589, max: 48)
#
# Run: 18, exploration: 0.15, score: 10
# Scores: (min: 8, avg: 13.166666666666666, max: 48)
#
# Run: 19, exploration: 0.15, score: 8
# Scores: (min: 8, avg: 12.894736842105264, max: 48)
#
# Run: 20, exploration: 0.15, score: 11
# Scores: (min: 8, avg: 12.8, max: 48)
#
# Run: 21, exploration: 0.15, score: 12
# Scores: (min: 8, avg: 12.761904761904763, max: 48)
#
# Run: 22, exploration: 0.15, score: 9
# Scores: (min: 8, avg: 12.590909090909092, max: 48)
#
# Run: 23, exploration: 0.15, score: 12
# Scores: (min: 8, avg: 12.565217391304348, max: 48)
#
# Run: 24, exploration: 0.15, score: 18
# Scores: (min: 8, avg: 12.791666666666666, max: 48)
#
# Run: 25, exploration: 0.15, score: 12
# Scores: (min: 8, avg: 12.76, max: 48)
#
# Run: 26, exploration: 0.15, score: 15
# Scores: (min: 8, avg: 12.846153846153847, max: 48)
#
# Run: 27, exploration: 0.15, score: 11
# Scores: (min: 8, avg: 12.777777777777779, max: 48)
#
# Run: 28, exploration: 0.15, score: 14
# Scores: (min: 8, avg: 12.821428571428571, max: 48)
#
# Run: 29, exploration: 0.15, score: 13
# Scores: (min: 8, avg: 12.827586206896552, max: 48)
#
# Run: 30, exploration: 0.15, score: 19
# Scores: (min: 8, avg: 13.033333333333333, max: 48)
#
# Run: 31, exploration: 0.15, score: 13
# Scores: (min: 8, avg: 13.03225806451613, max: 48)
#
# Run: 32, exploration: 0.15, score: 11
# Scores: (min: 8, avg: 12.96875, max: 48)
#
# Run: 33, exploration: 0.15, score: 27
# Scores: (min: 8, avg: 13.393939393939394, max: 48)
#
# Run: 34, exploration: 0.15, score: 31
# Scores: (min: 8, avg: 13.911764705882353, max: 48)
#
# Run: 35, exploration: 0.15, score: 30
# Scores: (min: 8, avg: 14.371428571428572, max: 48)
#
# Run: 36, exploration: 0.15, score: 33
# Scores: (min: 8, avg: 14.88888888888889, max: 48)
#
# Run: 37, exploration: 0.15, score: 31
# Scores: (min: 8, avg: 15.324324324324325, max: 48)
#
# Run: 38, exploration: 0.15, score: 27
# Scores: (min: 8, avg: 15.631578947368421, max: 48)
#
# Run: 39, exploration: 0.15, score: 51
# Scores: (min: 8, avg: 16.53846153846154, max: 51)
#
# Run: 40, exploration: 0.15, score: 26
# Scores: (min: 8, avg: 16.775, max: 51)
#
# Run: 41, exploration: 0.15, score: 29
# Scores: (min: 8, avg: 17.073170731707318, max: 51)
#
# Run: 42, exploration: 0.15, score: 32
# Scores: (min: 8, avg: 17.428571428571427, max: 51)
#
# Run: 43, exploration: 0.15, score: 49
# Scores: (min: 8, avg: 18.162790697674417, max: 51)
#
# Run: 44, exploration: 0.15, score: 78
# Scores: (min: 8, avg: 19.522727272727273, max: 78)
#
# Run: 45, exploration: 0.15, score: 55
# Scores: (min: 8, avg: 20.31111111111111, max: 78)
#
# Run: 46, exploration: 0.15, score: 134
# Scores: (min: 8, avg: 22.782608695652176, max: 134)
#
# Run: 47, exploration: 0.15, score: 55
# Scores: (min: 8, avg: 23.46808510638298, max: 134)
#
# Run: 48, exploration: 0.15, score: 71
# Scores: (min: 8, avg: 24.458333333333332, max: 134)
#
# Run: 49, exploration: 0.15, score: 77
# Scores: (min: 8, avg: 25.53061224489796, max: 134)
#
# Run: 50, exploration: 0.15, score: 92
# Scores: (min: 8, avg: 26.86, max: 134)
#
# Run: 51, exploration: 0.15, score: 88
# Scores: (min: 8, avg: 28.058823529411764, max: 134)
#
# Run: 52, exploration: 0.15, score: 116
# Scores: (min: 8, avg: 29.75, max: 134)
#
# Run: 53, exploration: 0.15, score: 68
# Scores: (min: 8, avg: 30.471698113207548, max: 134)
#
# Run: 54, exploration: 0.15, score: 106
# Scores: (min: 8, avg: 31.87037037037037, max: 134)
#
# Run: 55, exploration: 0.15, score: 62
# Scores: (min: 8, avg: 32.41818181818182, max: 134)
#
# Run: 56, exploration: 0.15, score: 63
# Scores: (min: 8, avg: 32.964285714285715, max: 134)
#
# Run: 57, exploration: 0.15, score: 227
# Scores: (min: 8, avg: 36.36842105263158, max: 227)
#
# Run: 58, exploration: 0.15, score: 83
# Scores: (min: 8, avg: 37.172413793103445, max: 227)
#
# Run: 59, exploration: 0.15, score: 140
# Scores: (min: 8, avg: 38.91525423728814, max: 227)
#
# Run: 60, exploration: 0.15, score: 116
# Scores: (min: 8, avg: 40.2, max: 227)
#
# Run: 61, exploration: 0.15, score: 500
# Scores: (min: 8, avg: 47.73770491803279, max: 500)
#
# Run: 62, exploration: 0.15, score: 211
# Scores: (min: 8, avg: 50.37096774193548, max: 500)
#
# Run: 63, exploration: 0.15, score: 388
# Scores: (min: 8, avg: 55.73015873015873, max: 500)
#
# Run: 64, exploration: 0.15, score: 258
# Scores: (min: 8, avg: 58.890625, max: 500)
#
# Run: 65, exploration: 0.15, score: 294
# Scores: (min: 8, avg: 62.50769230769231, max: 500)
#
# Run: 66, exploration: 0.15, score: 191
# Scores: (min: 8, avg: 64.45454545454545, max: 500)
#
# Run: 67, exploration: 0.15, score: 339
# Scores: (min: 8, avg: 68.55223880597015, max: 500)
#
# Run: 68, exploration: 0.15, score: 226
# Scores: (min: 8, avg: 70.86764705882354, max: 500)
#
# Run: 69, exploration: 0.15, score: 500
# Scores: (min: 8, avg: 77.08695652173913, max: 500)
#
# Run: 70, exploration: 0.15, score: 367
# Scores: (min: 8, avg: 81.22857142857143, max: 500)
#
# Run: 71, exploration: 0.15, score: 500
# Scores: (min: 8, avg: 87.12676056338029, max: 500)
#
# Run: 72, exploration: 0.15, score: 500
# Scores: (min: 8, avg: 92.86111111111111, max: 500)
#
# Run: 73, exploration: 0.15, score: 194
# Scores: (min: 8, avg: 94.24657534246575, max: 500)
#
# Run: 74, exploration: 0.15, score: 288
# Scores: (min: 8, avg: 96.86486486486487, max: 500)
#
# Run: 75, exploration: 0.15, score: 500
# Scores: (min: 8, avg: 102.24, max: 500)
#
# Run: 76, exploration: 0.15, score: 189
# Scores: (min: 8, avg: 103.38157894736842, max: 500)
#
# Run: 77, exploration: 0.15, score: 237
# Scores: (min: 8, avg: 105.11688311688312, max: 500)
#
# Run: 78, exploration: 0.15, score: 437
# Scores: (min: 8, avg: 109.37179487179488, max: 500)
#
# Run: 79, exploration: 0.15, score: 132
# Scores: (min: 8, avg: 109.65822784810126, max: 500)
#
# Run: 80, exploration: 0.15, score: 112
# Scores: (min: 8, avg: 109.6875, max: 500)
#
# Run: 81, exploration: 0.15, score: 189
# Scores: (min: 8, avg: 110.66666666666667, max: 500)
#
# Run: 82, exploration: 0.15, score: 69
# Scores: (min: 8, avg: 110.15853658536585, max: 500)
#
# Run: 83, exploration: 0.15, score: 116
# Scores: (min: 8, avg: 110.2289156626506, max: 500)
#
# Run: 84, exploration: 0.15, score: 187
# Scores: (min: 8, avg: 111.14285714285714, max: 500)
#
# Run: 85, exploration: 0.15, score: 138
# Scores: (min: 8, avg: 111.45882352941176, max: 500)
#
# Run: 86, exploration: 0.15, score: 266
# Scores: (min: 8, avg: 113.25581395348837, max: 500)
#
# Run: 87, exploration: 0.15, score: 105
# Scores: (min: 8, avg: 113.16091954022988, max: 500)
#
# Run: 88, exploration: 0.15, score: 150
# Scores: (min: 8, avg: 113.57954545454545, max: 500)
#
# Run: 89, exploration: 0.15, score: 190
# Scores: (min: 8, avg: 114.43820224719101, max: 500)
#
# Run: 90, exploration: 0.15, score: 169
# Scores: (min: 8, avg: 115.04444444444445, max: 500)
#
# Run: 91, exploration: 0.15, score: 79
# Scores: (min: 8, avg: 114.64835164835165, max: 500)
#
# Run: 92, exploration: 0.15, score: 118
# Scores: (min: 8, avg: 114.68478260869566, max: 500)
#
# Run: 93, exploration: 0.15, score: 500
# Scores: (min: 8, avg: 118.82795698924731, max: 500)
# Run: 94, exploration: 0.15, score: 340
# Scores: (min: 8, avg: 121.18085106382979, max: 500)
#
# Run: 95, exploration: 0.15, score: 125
# Scores: (min: 8, avg: 121.22105263157894, max: 500)
#
# Run: 96, exploration: 0.15, score: 179
# Scores: (min: 8, avg: 121.82291666666667, max: 500)
#
# Run: 97, exploration: 0.15, score: 308
# Scores: (min: 8, avg: 123.74226804123711, max: 500)
#
# Run: 98, exploration: 0.15, score: 500
# Scores: (min: 8, avg: 127.58163265306122, max: 500)
#
# Run: 99, exploration: 0.15, score: 194
# Scores: (min: 8, avg: 128.25252525252526, max: 500)
#
# Run: 100, exploration: 0.15, score: 198
# Scores: (min: 8, avg: 128.95, max: 500)
#
# Run: 101, exploration: 0.15, score: 148
# Scores: (min: 8, avg: 129.95, max: 500)
#
# Run: 102, exploration: 0.15, score: 500
# Scores: (min: 8, avg: 134.84, max: 500)
#
# Run: 103, exploration: 0.15, score: 116
# Scores: (min: 8, avg: 135.89, max: 500)
#
# Run: 104, exploration: 0.15, score: 208
# Scores: (min: 8, avg: 137.86, max: 500)
#
# Run: 105, exploration: 0.15, score: 500
# Scores: (min: 8, avg: 142.7, max: 500)
#
# Run: 106, exploration: 0.15, score: 500
# Scores: (min: 8, avg: 147.6, max: 500)
#
# Run: 107, exploration: 0.15, score: 500
# Scores: (min: 8, avg: 152.51, max: 500)
#
# Run: 108, exploration: 0.15, score: 463
# Scores: (min: 8, avg: 157.03, max: 500)
#
# Run: 109, exploration: 0.15, score: 98
# Scores: (min: 8, avg: 157.9, max: 500)
#
# Run: 110, exploration: 0.15, score: 171
# Scores: (min: 8, avg: 159.44, max: 500)
#
# Run: 111, exploration: 0.15, score: 356
# Scores: (min: 8, avg: 162.87, max: 500)
#
# Run: 112, exploration: 0.15, score: 144
# Scores: (min: 8, avg: 164.21, max: 500)
#
# Run: 113, exploration: 0.15, score: 326
# Scores: (min: 8, avg: 167.38, max: 500)
#
# Run: 114, exploration: 0.15, score: 272
# Scores: (min: 8, avg: 170.02, max: 500)
#
# Run: 115, exploration: 0.15, score: 361
# Scores: (min: 8, avg: 173.51, max: 500)
#
# Run: 116, exploration: 0.15, score: 62
# Scores: (min: 8, avg: 174.03, max: 500)
#
# Run: 117, exploration: 0.15, score: 14
# Scores: (min: 8, avg: 174.07, max: 500)
#
# Run: 118, exploration: 0.15, score: 13
# Scores: (min: 8, avg: 174.1, max: 500)
#
# Run: 119, exploration: 0.15, score: 12
# Scores: (min: 9, avg: 174.14, max: 500)
#
# Run: 120, exploration: 0.15, score: 15
# Scores: (min: 9, avg: 174.18, max: 500)
#
# Run: 121, exploration: 0.15, score: 307
# Scores: (min: 9, avg: 177.13, max: 500)
#
# Run: 122, exploration: 0.15, score: 187
# Scores: (min: 11, avg: 178.91, max: 500)
#
# Run: 123, exploration: 0.15, score: 176
# Scores: (min: 11, avg: 180.55, max: 500)
#
# Run: 124, exploration: 0.15, score: 184
# Scores: (min: 11, avg: 182.21, max: 500)
#
# Run: 125, exploration: 0.15, score: 500
# Scores: (min: 11, avg: 187.09, max: 500)
#
# Run: 126, exploration: 0.15, score: 122
# Scores: (min: 11, avg: 188.16, max: 500)
#
# Run: 127, exploration: 0.15, score: 324
# Scores: (min: 11, avg: 191.29, max: 500)
#
# Run: 128, exploration: 0.15, score: 159
# Scores: (min: 11, avg: 192.74, max: 500)
#
# Run: 129, exploration: 0.15, score: 98
# Scores: (min: 11, avg: 193.59, max: 500)
#
# Run: 130, exploration: 0.15, score: 287
# Scores: (min: 11, avg: 196.27, max: 500)
#
# Solved in 30 runs, 130 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-2-df8851f61d46> in cartpole()
#      88             if terminal:
#      89                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 90                 score_logger.add_score(step, run)
#      91                 break
#      92             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
## Second Modification

## I modified the GAMMA factor by modifying the discount factor to 0.80
## Solved in 84 runs, 184 total runs.

import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.80  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.7450264374814737, score: 29
# Scores: (min: 29, avg: 29, max: 29)
#
# Run: 2, exploration: 0.4863802860551433, score: 15
# Scores: (min: 15, avg: 22, max: 29)
#
# Run: 3, exploration: 0.34790850104962573, score: 12
# Scores: (min: 12, avg: 18.666666666666668, max: 29)
#
# Run: 4, exploration: 0.25655612262584343, score: 11
# Scores: (min: 11, avg: 16.75, max: 29)
#
# Run: 5, exploration: 0.16748914405478274, score: 15
# Scores: (min: 11, avg: 16.4, max: 29)
#
# Run: 6, exploration: 0.15, score: 11
# Scores: (min: 11, avg: 15.5, max: 29)
#
# Run: 7, exploration: 0.15, score: 9
# Scores: (min: 9, avg: 14.571428571428571, max: 29)
#
# Run: 8, exploration: 0.15, score: 8
# Scores: (min: 8, avg: 13.75, max: 29)
#
# Run: 9, exploration: 0.15, score: 12
# Scores: (min: 8, avg: 13.555555555555555, max: 29)
#
# Run: 10, exploration: 0.15, score: 10
# Scores: (min: 8, avg: 13.2, max: 29)
#
# Run: 11, exploration: 0.15, score: 9
# Scores: (min: 8, avg: 12.818181818181818, max: 29)
#
# Run: 12, exploration: 0.15, score: 9
# Scores: (min: 8, avg: 12.5, max: 29)
#
# Run: 13, exploration: 0.15, score: 9
# Scores: (min: 8, avg: 12.23076923076923, max: 29)
#
# Run: 14, exploration: 0.15, score: 11
# Scores: (min: 8, avg: 12.142857142857142, max: 29)
#
# Run: 15, exploration: 0.15, score: 9
# Scores: (min: 8, avg: 11.933333333333334, max: 29)
#
# Run: 16, exploration: 0.15, score: 10
# Scores: (min: 8, avg: 11.8125, max: 29)
#
# Run: 17, exploration: 0.15, score: 9
# Scores: (min: 8, avg: 11.647058823529411, max: 29)
#
# Run: 18, exploration: 0.15, score: 9
# Scores: (min: 8, avg: 11.5, max: 29)
#
# Run: 19, exploration: 0.15, score: 11
# Scores: (min: 8, avg: 11.473684210526315, max: 29)
#
# Run: 20, exploration: 0.15, score: 11
# Scores: (min: 8, avg: 11.45, max: 29)
#
# Run: 21, exploration: 0.15, score: 12
# Scores: (min: 8, avg: 11.476190476190476, max: 29)
#
# Run: 22, exploration: 0.15, score: 11
# Scores: (min: 8, avg: 11.454545454545455, max: 29)
#
# Run: 23, exploration: 0.15, score: 11
# Scores: (min: 8, avg: 11.434782608695652, max: 29)
#
# Run: 24, exploration: 0.15, score: 10
# Scores: (min: 8, avg: 11.375, max: 29)
#
# Run: 25, exploration: 0.15, score: 13
# Scores: (min: 8, avg: 11.44, max: 29)
#
# Run: 26, exploration: 0.15, score: 9
# Scores: (min: 8, avg: 11.346153846153847, max: 29)
#
# Run: 27, exploration: 0.15, score: 48
# Scores: (min: 8, avg: 12.703703703703704, max: 48)
#
# Run: 28, exploration: 0.15, score: 23
# Scores: (min: 8, avg: 13.071428571428571, max: 48)
#
# Run: 29, exploration: 0.15, score: 28
# Scores: (min: 8, avg: 13.586206896551724, max: 48)
#
# Run: 30, exploration: 0.15, score: 41
# Scores: (min: 8, avg: 14.5, max: 48)
#
# Run: 31, exploration: 0.15, score: 44
# Scores: (min: 8, avg: 15.451612903225806, max: 48)
#
# Run: 32, exploration: 0.15, score: 43
# Scores: (min: 8, avg: 16.3125, max: 48)
#
# Run: 33, exploration: 0.15, score: 139
# Scores: (min: 8, avg: 20.03030303030303, max: 139)
#
# Run: 34, exploration: 0.15, score: 62
# Scores: (min: 8, avg: 21.264705882352942, max: 139)
#
# Run: 35, exploration: 0.15, score: 77
# Scores: (min: 8, avg: 22.857142857142858, max: 139)
#
# Run: 36, exploration: 0.15, score: 205
# Scores: (min: 8, avg: 27.916666666666668, max: 205)
#
# Run: 37, exploration: 0.15, score: 204
# Scores: (min: 8, avg: 32.67567567567568, max: 205)
#
# Run: 38, exploration: 0.15, score: 88
# Scores: (min: 8, avg: 34.13157894736842, max: 205)
#
# Run: 39, exploration: 0.15, score: 98
# Scores: (min: 8, avg: 35.76923076923077, max: 205)
#
# Run: 40, exploration: 0.15, score: 163
# Scores: (min: 8, avg: 38.95, max: 205)
#
# Run: 41, exploration: 0.15, score: 220
# Scores: (min: 8, avg: 43.36585365853659, max: 220)
#
# Run: 42, exploration: 0.15, score: 159
# Scores: (min: 8, avg: 46.11904761904762, max: 220)
#
# Run: 43, exploration: 0.15, score: 420
# Scores: (min: 8, avg: 54.81395348837209, max: 420)
#
# Run: 44, exploration: 0.15, score: 204
# Scores: (min: 8, avg: 58.20454545454545, max: 420)
#
# Run: 45, exploration: 0.15, score: 173
# Scores: (min: 8, avg: 60.75555555555555, max: 420)
#
# Run: 46, exploration: 0.15, score: 186
# Scores: (min: 8, avg: 63.47826086956522, max: 420)
#
# Run: 47, exploration: 0.15, score: 179
# Scores: (min: 8, avg: 65.93617021276596, max: 420)
#
# Run: 48, exploration: 0.15, score: 266
# Scores: (min: 8, avg: 70.10416666666667, max: 420)
#
# Run: 49, exploration: 0.15, score: 214
# Scores: (min: 8, avg: 73.04081632653062, max: 420)
#
# Run: 50, exploration: 0.15, score: 199
# Scores: (min: 8, avg: 75.56, max: 420)
#
# Run: 51, exploration: 0.15, score: 161
# Scores: (min: 8, avg: 77.23529411764706, max: 420)
#
# Run: 52, exploration: 0.15, score: 194
# Scores: (min: 8, avg: 79.48076923076923, max: 420)
#
# Run: 53, exploration: 0.15, score: 378
# Scores: (min: 8, avg: 85.11320754716981, max: 420)
#
# Run: 54, exploration: 0.15, score: 188
# Scores: (min: 8, avg: 87.01851851851852, max: 420)
#
# Run: 55, exploration: 0.15, score: 199
# Scores: (min: 8, avg: 89.05454545454545, max: 420)
#
# Run: 56, exploration: 0.15, score: 311
# Scores: (min: 8, avg: 93.01785714285714, max: 420)
#
# Run: 57, exploration: 0.15, score: 162
# Scores: (min: 8, avg: 94.2280701754386, max: 420)
#
# Run: 58, exploration: 0.15, score: 144
# Scores: (min: 8, avg: 95.08620689655173, max: 420)
#
# Run: 59, exploration: 0.15, score: 321
# Scores: (min: 8, avg: 98.91525423728814, max: 420)
#
# Run: 60, exploration: 0.15, score: 152
# Scores: (min: 8, avg: 99.8, max: 420)
#
# Run: 61, exploration: 0.15, score: 159
# Scores: (min: 8, avg: 100.77049180327869, max: 420)
#
# Run: 62, exploration: 0.15, score: 200
# Scores: (min: 8, avg: 102.37096774193549, max: 420)
#
# Run: 63, exploration: 0.15, score: 177
# Scores: (min: 8, avg: 103.55555555555556, max: 420)
#
# Run: 64, exploration: 0.15, score: 209
# Scores: (min: 8, avg: 105.203125, max: 420)
#
# Run: 65, exploration: 0.15, score: 265
# Scores: (min: 8, avg: 107.66153846153846, max: 420)
#
# Run: 66, exploration: 0.15, score: 169
# Scores: (min: 8, avg: 108.5909090909091, max: 420)
#
# Run: 67, exploration: 0.15, score: 375
# Scores: (min: 8, avg: 112.56716417910448, max: 420)
#
# Run: 68, exploration: 0.15, score: 163
# Scores: (min: 8, avg: 113.30882352941177, max: 420)
#
# Run: 69, exploration: 0.15, score: 160
# Scores: (min: 8, avg: 113.98550724637681, max: 420)
#
# Run: 70, exploration: 0.15, score: 173
# Scores: (min: 8, avg: 114.82857142857142, max: 420)
#
# Run: 71, exploration: 0.15, score: 143
# Scores: (min: 8, avg: 115.22535211267606, max: 420)
#
# Run: 72, exploration: 0.15, score: 184
# Scores: (min: 8, avg: 116.18055555555556, max: 420)
#
# Run: 73, exploration: 0.15, score: 178
# Scores: (min: 8, avg: 117.02739726027397, max: 420)
#
# Run: 74, exploration: 0.15, score: 145
# Scores: (min: 8, avg: 117.4054054054054, max: 420)
#
# Run: 75, exploration: 0.15, score: 240
# Scores: (min: 8, avg: 119.04, max: 420)
#
# Run: 76, exploration: 0.15, score: 213
# Scores: (min: 8, avg: 120.27631578947368, max: 420)
#
# Run: 77, exploration: 0.15, score: 180
# Scores: (min: 8, avg: 121.05194805194805, max: 420)
#
# Run: 78, exploration: 0.15, score: 183
# Scores: (min: 8, avg: 121.84615384615384, max: 420)
#
# Run: 79, exploration: 0.15, score: 328
# Scores: (min: 8, avg: 124.45569620253164, max: 420)
#
# Run: 80, exploration: 0.15, score: 158
# Scores: (min: 8, avg: 124.875, max: 420)
#
# Run: 81, exploration: 0.15, score: 171
# Scores: (min: 8, avg: 125.44444444444444, max: 420)
#
# Run: 82, exploration: 0.15, score: 218
# Scores: (min: 8, avg: 126.57317073170732, max: 420)
#
# Run: 83, exploration: 0.15, score: 173
# Scores: (min: 8, avg: 127.13253012048193, max: 420)
#
# Run: 84, exploration: 0.15, score: 170
# Scores: (min: 8, avg: 127.64285714285714, max: 420)
#
# Run: 85, exploration: 0.15, score: 118
# Scores: (min: 8, avg: 127.52941176470588, max: 420)
#
# Run: 86, exploration: 0.15, score: 173
# Scores: (min: 8, avg: 128.0581395348837, max: 420)
#
# Run: 87, exploration: 0.15, score: 158
# Scores: (min: 8, avg: 128.4022988505747, max: 420)
#
# Run: 88, exploration: 0.15, score: 152
# Scores: (min: 8, avg: 128.67045454545453, max: 420)
#
# Run: 89, exploration: 0.15, score: 24
# Scores: (min: 8, avg: 127.49438202247191, max: 420)
#
# Run: 90, exploration: 0.15, score: 182
# Scores: (min: 8, avg: 128.1, max: 420)
#
# Run: 91, exploration: 0.15, score: 149
# Scores: (min: 8, avg: 128.32967032967034, max: 420)
#
# Run: 92, exploration: 0.15, score: 149
# Scores: (min: 8, avg: 128.55434782608697, max: 420)
#
# Run: 93, exploration: 0.15, score: 144
# Scores: (min: 8, avg: 128.72043010752688, max: 420)
# Run: 94, exploration: 0.15, score: 32
# Scores: (min: 8, avg: 127.69148936170212, max: 420)
#
# Run: 95, exploration: 0.15, score: 367
# Scores: (min: 8, avg: 130.21052631578948, max: 420)
#
# Run: 96, exploration: 0.15, score: 32
# Scores: (min: 8, avg: 129.1875, max: 420)
#
# Run: 97, exploration: 0.15, score: 17
# Scores: (min: 8, avg: 128.03092783505156, max: 420)
#
# Run: 98, exploration: 0.15, score: 237
# Scores: (min: 8, avg: 129.14285714285714, max: 420)
#
# Run: 99, exploration: 0.15, score: 213
# Scores: (min: 8, avg: 129.989898989899, max: 420)
#
# Run: 100, exploration: 0.15, score: 139
# Scores: (min: 8, avg: 130.08, max: 420)
#
# Run: 101, exploration: 0.15, score: 119
# Scores: (min: 8, avg: 130.98, max: 420)
#
# Run: 102, exploration: 0.15, score: 111
# Scores: (min: 8, avg: 131.94, max: 420)
#
# Run: 103, exploration: 0.15, score: 198
# Scores: (min: 8, avg: 133.8, max: 420)
#
# Run: 104, exploration: 0.15, score: 190
# Scores: (min: 8, avg: 135.59, max: 420)
#
# Run: 105, exploration: 0.15, score: 293
# Scores: (min: 8, avg: 138.37, max: 420)
#
# Run: 106, exploration: 0.15, score: 102
# Scores: (min: 8, avg: 139.28, max: 420)
#
# Run: 107, exploration: 0.15, score: 92
# Scores: (min: 8, avg: 140.11, max: 420)
#
# Run: 108, exploration: 0.15, score: 41
# Scores: (min: 9, avg: 140.44, max: 420)
#
# Run: 109, exploration: 0.15, score: 273
# Scores: (min: 9, avg: 143.05, max: 420)
#
# Run: 110, exploration: 0.15, score: 148
# Scores: (min: 9, avg: 144.43, max: 420)
#
# Run: 111, exploration: 0.15, score: 138
# Scores: (min: 9, avg: 145.72, max: 420)
#
# Run: 112, exploration: 0.15, score: 80
# Scores: (min: 9, avg: 146.43, max: 420)
#
# Run: 113, exploration: 0.15, score: 238
# Scores: (min: 9, avg: 148.72, max: 420)
#
# Run: 114, exploration: 0.15, score: 36
# Scores: (min: 9, avg: 148.97, max: 420)
#
# Run: 115, exploration: 0.15, score: 17
# Scores: (min: 9, avg: 149.05, max: 420)
#
# Run: 116, exploration: 0.15, score: 12
# Scores: (min: 9, avg: 149.07, max: 420)
#
# Run: 117, exploration: 0.15, score: 14
# Scores: (min: 9, avg: 149.12, max: 420)
#
# Run: 118, exploration: 0.15, score: 25
# Scores: (min: 9, avg: 149.28, max: 420)
#
# Run: 119, exploration: 0.15, score: 125
# Scores: (min: 9, avg: 150.42, max: 420)
#
# Run: 120, exploration: 0.15, score: 133
# Scores: (min: 9, avg: 151.64, max: 420)
#
# Run: 121, exploration: 0.15, score: 212
# Scores: (min: 9, avg: 153.64, max: 420)
#
# Run: 122, exploration: 0.15, score: 137
# Scores: (min: 9, avg: 154.9, max: 420)
#
# Run: 123, exploration: 0.15, score: 123
# Scores: (min: 9, avg: 156.02, max: 420)
#
# Run: 124, exploration: 0.15, score: 87
# Scores: (min: 9, avg: 156.79, max: 420)
#
# Run: 125, exploration: 0.15, score: 258
# Scores: (min: 9, avg: 159.24, max: 420)
#
# Run: 126, exploration: 0.15, score: 80
# Scores: (min: 12, avg: 159.95, max: 420)
#
# Run: 127, exploration: 0.15, score: 146
# Scores: (min: 12, avg: 160.93, max: 420)
#
# Run: 128, exploration: 0.15, score: 194
# Scores: (min: 12, avg: 162.64, max: 420)
#
# Run: 129, exploration: 0.15, score: 283
# Scores: (min: 12, avg: 165.19, max: 420)
#
# Run: 130, exploration: 0.15, score: 325
# Scores: (min: 12, avg: 168.03, max: 420)
#
# Run: 131, exploration: 0.15, score: 214
# Scores: (min: 12, avg: 169.73, max: 420)
#
# Run: 132, exploration: 0.15, score: 40
# Scores: (min: 12, avg: 169.7, max: 420)
#
# Run: 133, exploration: 0.15, score: 218
# Scores: (min: 12, avg: 170.49, max: 420)
#
# Run: 134, exploration: 0.15, score: 140
# Scores: (min: 12, avg: 171.27, max: 420)
#
# Run: 135, exploration: 0.15, score: 176
# Scores: (min: 12, avg: 172.26, max: 420)
#
# Run: 136, exploration: 0.15, score: 267
# Scores: (min: 12, avg: 172.88, max: 420)
#
# Run: 137, exploration: 0.15, score: 251
# Scores: (min: 12, avg: 173.35, max: 420)
#
# Run: 138, exploration: 0.15, score: 217
# Scores: (min: 12, avg: 174.64, max: 420)
#
# Run: 139, exploration: 0.15, score: 384
# Scores: (min: 12, avg: 177.5, max: 420)
#
# Run: 140, exploration: 0.15, score: 290
# Scores: (min: 12, avg: 178.77, max: 420)
#
# Run: 141, exploration: 0.15, score: 171
# Scores: (min: 12, avg: 178.28, max: 420)
#
# Run: 142, exploration: 0.15, score: 256
# Scores: (min: 12, avg: 179.25, max: 420)
#
# Run: 143, exploration: 0.15, score: 229
# Scores: (min: 12, avg: 177.34, max: 384)
#
# Run: 144, exploration: 0.15, score: 182
# Scores: (min: 12, avg: 177.12, max: 384)
#
# Run: 145, exploration: 0.15, score: 348
# Scores: (min: 12, avg: 178.87, max: 384)
#
# Run: 146, exploration: 0.15, score: 500
# Scores: (min: 12, avg: 182.01, max: 500)
#
# Run: 147, exploration: 0.15, score: 397
# Scores: (min: 12, avg: 184.19, max: 500)
#
# Run: 148, exploration: 0.15, score: 17
# Scores: (min: 12, avg: 181.7, max: 500)
#
# Run: 149, exploration: 0.15, score: 14
# Scores: (min: 12, avg: 179.7, max: 500)
#
# Run: 150, exploration: 0.15, score: 13
# Scores: (min: 12, avg: 177.84, max: 500)
#
# Run: 151, exploration: 0.15, score: 500
# Scores: (min: 12, avg: 181.23, max: 500)
#
# Run: 152, exploration: 0.15, score: 68
# Scores: (min: 12, avg: 179.97, max: 500)
#
# Run: 153, exploration: 0.15, score: 500
# Scores: (min: 12, avg: 181.19, max: 500)
#
# Run: 154, exploration: 0.15, score: 500
# Scores: (min: 12, avg: 184.31, max: 500)
#
# Run: 155, exploration: 0.15, score: 259
# Scores: (min: 12, avg: 184.91, max: 500)
#
# Run: 156, exploration: 0.15, score: 237
# Scores: (min: 12, avg: 184.17, max: 500)
#
# Run: 157, exploration: 0.15, score: 500
# Scores: (min: 12, avg: 187.55, max: 500)
#
# Run: 158, exploration: 0.15, score: 54
# Scores: (min: 12, avg: 186.65, max: 500)
#
# Run: 159, exploration: 0.15, score: 16
# Scores: (min: 12, avg: 183.6, max: 500)
#
# Run: 160, exploration: 0.15, score: 11
# Scores: (min: 11, avg: 182.19, max: 500)
#
# Run: 161, exploration: 0.15, score: 13
# Scores: (min: 11, avg: 180.73, max: 500)
#
# Run: 162, exploration: 0.15, score: 16
# Scores: (min: 11, avg: 178.89, max: 500)
#
# Run: 163, exploration: 0.15, score: 204
# Scores: (min: 11, avg: 179.16, max: 500)
#
# Run: 164, exploration: 0.15, score: 343
# Scores: (min: 11, avg: 180.5, max: 500)
#
# Run: 165, exploration: 0.15, score: 370
# Scores: (min: 11, avg: 181.55, max: 500)
#
# Run: 166, exploration: 0.15, score: 36
# Scores: (min: 11, avg: 180.22, max: 500)
#
# Run: 167, exploration: 0.15, score: 446
# Scores: (min: 11, avg: 180.93, max: 500)
#
# Run: 168, exploration: 0.15, score: 19
# Scores: (min: 11, avg: 179.49, max: 500)
#
# Run: 169, exploration: 0.15, score: 112
# Scores: (min: 11, avg: 179.01, max: 500)
#
# Run: 170, exploration: 0.15, score: 500
# Scores: (min: 11, avg: 182.28, max: 500)
#
# Run: 171, exploration: 0.15, score: 288
# Scores: (min: 11, avg: 183.73, max: 500)
#
# Run: 172, exploration: 0.15, score: 144
# Scores: (min: 11, avg: 183.33, max: 500)
#
# Run: 173, exploration: 0.15, score: 500
# Scores: (min: 11, avg: 186.55, max: 500)
#
# Run: 174, exploration: 0.15, score: 322
# Scores: (min: 11, avg: 188.32, max: 500)
#
# Run: 175, exploration: 0.15, score: 238
# Scores: (min: 11, avg: 188.3, max: 500)
#
# Run: 176, exploration: 0.15, score: 303
# Scores: (min: 11, avg: 189.2, max: 500)
#
# Run: 177, exploration: 0.15, score: 169
# Scores: (min: 11, avg: 189.09, max: 500)
#
# Run: 178, exploration: 0.15, score: 329
# Scores: (min: 11, avg: 190.55, max: 500)
#
# Run: 179, exploration: 0.15, score: 246
# Scores: (min: 11, avg: 189.73, max: 500)
#
# Run: 180, exploration: 0.15, score: 78
# Scores: (min: 11, avg: 188.93, max: 500)
#
# Run: 181, exploration: 0.15, score: 91
# Scores: (min: 11, avg: 188.13, max: 500)
#
# Run: 182, exploration: 0.15, score: 443
# Scores: (min: 11, avg: 190.38, max: 500)
#
# Run: 183, exploration: 0.15, score: 398
# Scores: (min: 11, avg: 192.63, max: 500)
#
# Run: 184, exploration: 0.15, score: 500
# Scores: (min: 11, avg: 195.93, max: 500)
#
# Solved in 84 runs, 184 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-2-df8851f61d46> in cartpole()
#      88             if terminal:
#      89                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 90                 score_logger.add_score(step, run)
#      91                 break
#      92             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
## Third Modification

## I modified the Learning factor by changing the value from 0.001 to 0.01 

import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.01  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.7450264374814737, score: 29
# Scores: (min: 29, avg: 29, max: 29)
#
# Run: 2, exploration: 0.5494004701734145, score: 11
# Scores: (min: 11, avg: 20, max: 29)
#
# Run: 3, exploration: 0.35866855778311935, score: 15
# Scores: (min: 11, avg: 18.333333333333332, max: 29)
#
# Run: 4, exploration: 0.24139365577865607, score: 14
# Scores: (min: 11, avg: 17.25, max: 29)
#
# Run: 5, exploration: 0.15759053564114506, score: 15
# Scores: (min: 11, avg: 16.8, max: 29)
#
# Run: 6, exploration: 0.15, score: 9
# Scores: (min: 9, avg: 15.5, max: 29)
#
# Run: 7, exploration: 0.15, score: 9
# Scores: (min: 9, avg: 14.571428571428571, max: 29)
#
# Run: 8, exploration: 0.15, score: 11
# Scores: (min: 9, avg: 14.125, max: 29)
#
# Run: 9, exploration: 0.15, score: 14
# Scores: (min: 9, avg: 14.11111111111111, max: 29)
#
# Run: 10, exploration: 0.15, score: 12
# Scores: (min: 9, avg: 13.9, max: 29)
#
# Run: 11, exploration: 0.15, score: 11
# Scores: (min: 9, avg: 13.636363636363637, max: 29)
#
# Run: 12, exploration: 0.15, score: 8
# Scores: (min: 8, avg: 13.166666666666666, max: 29)
#
# Run: 13, exploration: 0.15, score: 10
# Scores: (min: 8, avg: 12.923076923076923, max: 29)
#
# Run: 14, exploration: 0.15, score: 9
# Scores: (min: 8, avg: 12.642857142857142, max: 29)
#
# Run: 15, exploration: 0.15, score: 10
# Scores: (min: 8, avg: 12.466666666666667, max: 29)
#
# Run: 16, exploration: 0.15, score: 10
# Scores: (min: 8, avg: 12.3125, max: 29)
#
# Run: 17, exploration: 0.15, score: 11
# Scores: (min: 8, avg: 12.235294117647058, max: 29)
#
# Run: 18, exploration: 0.15, score: 9
# Scores: (min: 8, avg: 12.055555555555555, max: 29)
#
# Run: 19, exploration: 0.15, score: 10
# Scores: (min: 8, avg: 11.947368421052632, max: 29)
#
# Run: 20, exploration: 0.15, score: 34
# Scores: (min: 8, avg: 13.05, max: 34)
#
# Run: 21, exploration: 0.15, score: 28
# Scores: (min: 8, avg: 13.761904761904763, max: 34)
#
# Run: 22, exploration: 0.15, score: 38
# Scores: (min: 8, avg: 14.863636363636363, max: 38)
#
# Run: 23, exploration: 0.15, score: 30
# Scores: (min: 8, avg: 15.521739130434783, max: 38)
#
# Run: 24, exploration: 0.15, score: 49
# Scores: (min: 8, avg: 16.916666666666668, max: 49)
#
# Run: 25, exploration: 0.15, score: 37
# Scores: (min: 8, avg: 17.72, max: 49)
#
# Run: 26, exploration: 0.15, score: 47
# Scores: (min: 8, avg: 18.846153846153847, max: 49)
#
# Run: 27, exploration: 0.15, score: 90
# Scores: (min: 8, avg: 21.48148148148148, max: 90)
#
# Run: 28, exploration: 0.15, score: 90
# Scores: (min: 8, avg: 23.928571428571427, max: 90)
#
# Run: 29, exploration: 0.15, score: 75
# Scores: (min: 8, avg: 25.689655172413794, max: 90)
#
# Run: 30, exploration: 0.15, score: 66
# Scores: (min: 8, avg: 27.033333333333335, max: 90)
#
# Run: 31, exploration: 0.15, score: 37
# Scores: (min: 8, avg: 27.35483870967742, max: 90)
#
# Run: 32, exploration: 0.15, score: 55
# Scores: (min: 8, avg: 28.21875, max: 90)
#
# Run: 33, exploration: 0.15, score: 65
# Scores: (min: 8, avg: 29.333333333333332, max: 90)
#
# Run: 34, exploration: 0.15, score: 49
# Scores: (min: 8, avg: 29.91176470588235, max: 90)
#
# Run: 35, exploration: 0.15, score: 94
# Scores: (min: 8, avg: 31.742857142857144, max: 94)
#
# Run: 36, exploration: 0.15, score: 210
# Scores: (min: 8, avg: 36.69444444444444, max: 210)
#
# Run: 37, exploration: 0.15, score: 118
# Scores: (min: 8, avg: 38.891891891891895, max: 210)
#
# Run: 38, exploration: 0.15, score: 119
# Scores: (min: 8, avg: 41, max: 210)
#
# Run: 39, exploration: 0.15, score: 281
# Scores: (min: 8, avg: 47.15384615384615, max: 281)
#
# Run: 40, exploration: 0.15, score: 395
# Scores: (min: 8, avg: 55.85, max: 395)
#
# Run: 41, exploration: 0.15, score: 360
# Scores: (min: 8, avg: 63.26829268292683, max: 395)
#
# Run: 42, exploration: 0.15, score: 229
# Scores: (min: 8, avg: 67.21428571428571, max: 395)
#
# Run: 43, exploration: 0.15, score: 192
# Scores: (min: 8, avg: 70.11627906976744, max: 395)
#
# Run: 44, exploration: 0.15, score: 177
# Scores: (min: 8, avg: 72.54545454545455, max: 395)
#
# Run: 45, exploration: 0.15, score: 154
# Scores: (min: 8, avg: 74.35555555555555, max: 395)
#
# Run: 46, exploration: 0.15, score: 178
# Scores: (min: 8, avg: 76.6086956521739, max: 395)
#
# Run: 47, exploration: 0.15, score: 170
# Scores: (min: 8, avg: 78.59574468085107, max: 395)
#
# Run: 48, exploration: 0.15, score: 180
# Scores: (min: 8, avg: 80.70833333333333, max: 395)
#
# Run: 49, exploration: 0.15, score: 171
# Scores: (min: 8, avg: 82.55102040816327, max: 395)
#
# Run: 50, exploration: 0.15, score: 146
# Scores: (min: 8, avg: 83.82, max: 395)
#
# Run: 51, exploration: 0.15, score: 247
# Scores: (min: 8, avg: 87.01960784313725, max: 395)
#
# Run: 52, exploration: 0.15, score: 190
# Scores: (min: 8, avg: 89, max: 395)
#
# Run: 53, exploration: 0.15, score: 174
# Scores: (min: 8, avg: 90.60377358490567, max: 395)
#
# Run: 54, exploration: 0.15, score: 176
# Scores: (min: 8, avg: 92.18518518518519, max: 395)
#
# Run: 55, exploration: 0.15, score: 182
# Scores: (min: 8, avg: 93.81818181818181, max: 395)
#
# Run: 56, exploration: 0.15, score: 176
# Scores: (min: 8, avg: 95.28571428571429, max: 395)
#
# Run: 57, exploration: 0.15, score: 163
# Scores: (min: 8, avg: 96.47368421052632, max: 395)
#
# Run: 58, exploration: 0.15, score: 183
# Scores: (min: 8, avg: 97.96551724137932, max: 395)
#
# Run: 59, exploration: 0.15, score: 214
# Scores: (min: 8, avg: 99.9322033898305, max: 395)
#
# Run: 60, exploration: 0.15, score: 190
# Scores: (min: 8, avg: 101.43333333333334, max: 395)
#
# Run: 61, exploration: 0.15, score: 239
# Scores: (min: 8, avg: 103.68852459016394, max: 395)
#
# Run: 62, exploration: 0.15, score: 203
# Scores: (min: 8, avg: 105.29032258064517, max: 395)
#
# Run: 63, exploration: 0.15, score: 213
# Scores: (min: 8, avg: 107, max: 395)
#
# Run: 64, exploration: 0.15, score: 25
# Scores: (min: 8, avg: 105.71875, max: 395)
#
# Run: 65, exploration: 0.15, score: 292
# Scores: (min: 8, avg: 108.58461538461539, max: 395)
#
# Run: 66, exploration: 0.15, score: 257
# Scores: (min: 8, avg: 110.83333333333333, max: 395)
#
# Run: 67, exploration: 0.15, score: 217
# Scores: (min: 8, avg: 112.41791044776119, max: 395)
#
# Run: 68, exploration: 0.15, score: 137
# Scores: (min: 8, avg: 112.77941176470588, max: 395)
#
# Run: 69, exploration: 0.15, score: 267
# Scores: (min: 8, avg: 115.01449275362319, max: 395)
#
# Run: 70, exploration: 0.15, score: 210
# Scores: (min: 8, avg: 116.37142857142857, max: 395)
#
# Run: 71, exploration: 0.15, score: 66
# Scores: (min: 8, avg: 115.66197183098592, max: 395)
#
# Run: 72, exploration: 0.15, score: 385
# Scores: (min: 8, avg: 119.40277777777777, max: 395)
#
# Run: 73, exploration: 0.15, score: 160
# Scores: (min: 8, avg: 119.95890410958904, max: 395)
#
# Run: 74, exploration: 0.15, score: 202
# Scores: (min: 8, avg: 121.06756756756756, max: 395)
#
# Run: 75, exploration: 0.15, score: 167
# Scores: (min: 8, avg: 121.68, max: 395)
#
# Run: 76, exploration: 0.15, score: 207
# Scores: (min: 8, avg: 122.80263157894737, max: 395)
#
# Run: 77, exploration: 0.15, score: 266
# Scores: (min: 8, avg: 124.66233766233766, max: 395)
#
# Run: 78, exploration: 0.15, score: 171
# Scores: (min: 8, avg: 125.25641025641026, max: 395)
#
# Run: 79, exploration: 0.15, score: 87
# Scores: (min: 8, avg: 124.77215189873418, max: 395)
#
# Run: 80, exploration: 0.15, score: 55
# Scores: (min: 8, avg: 123.9, max: 395)
#
# Run: 81, exploration: 0.15, score: 217
# Scores: (min: 8, avg: 125.04938271604938, max: 395)
#
# Run: 82, exploration: 0.15, score: 138
# Scores: (min: 8, avg: 125.20731707317073, max: 395)
#
# Run: 83, exploration: 0.15, score: 150
# Scores: (min: 8, avg: 125.50602409638554, max: 395)
#
# Run: 84, exploration: 0.15, score: 135
# Scores: (min: 8, avg: 125.61904761904762, max: 395)
#
# Run: 85, exploration: 0.15, score: 186
# Scores: (min: 8, avg: 126.32941176470588, max: 395)
#
# Run: 86, exploration: 0.15, score: 151
# Scores: (min: 8, avg: 126.61627906976744, max: 395)
#
# Run: 87, exploration: 0.15, score: 188
# Scores: (min: 8, avg: 127.32183908045977, max: 395)
#
# Run: 88, exploration: 0.15, score: 178
# Scores: (min: 8, avg: 127.89772727272727, max: 395)
#
# Run: 89, exploration: 0.15, score: 26
# Scores: (min: 8, avg: 126.75280898876404, max: 395)
#
# Run: 90, exploration: 0.15, score: 180
# Scores: (min: 8, avg: 127.34444444444445, max: 395)
#
# Run: 91, exploration: 0.15, score: 243
# Scores: (min: 8, avg: 128.6153846153846, max: 395)
#
# Run: 92, exploration: 0.15, score: 122
# Scores: (min: 8, avg: 128.54347826086956, max: 395)
#
# Run: 93, exploration: 0.15, score: 197
# Scores: (min: 8, avg: 129.27956989247312, max: 395)
# Run: 94, exploration: 0.15, score: 211
# Scores: (min: 8, avg: 130.14893617021278, max: 395)
#
# Run: 95, exploration: 0.15, score: 157
# Scores: (min: 8, avg: 130.43157894736842, max: 395)
#
# Run: 96, exploration: 0.15, score: 20
# Scores: (min: 8, avg: 129.28125, max: 395)
#
# Run: 97, exploration: 0.15, score: 14
# Scores: (min: 8, avg: 128.09278350515464, max: 395)
#
# Run: 98, exploration: 0.15, score: 142
# Scores: (min: 8, avg: 128.23469387755102, max: 395)
#
# Run: 99, exploration: 0.15, score: 159
# Scores: (min: 8, avg: 128.54545454545453, max: 395)
#
# Run: 100, exploration: 0.15, score: 74
# Scores: (min: 8, avg: 128, max: 395)
#
# Run: 101, exploration: 0.15, score: 113
# Scores: (min: 8, avg: 128.84, max: 395)
#
# Run: 102, exploration: 0.15, score: 129
# Scores: (min: 8, avg: 130.02, max: 395)
#
# Run: 103, exploration: 0.15, score: 154
# Scores: (min: 8, avg: 131.41, max: 395)
#
# Run: 104, exploration: 0.15, score: 383
# Scores: (min: 8, avg: 135.1, max: 395)
#
# Run: 105, exploration: 0.15, score: 263
# Scores: (min: 8, avg: 137.58, max: 395)
#
# Run: 106, exploration: 0.15, score: 220
# Scores: (min: 8, avg: 139.69, max: 395)
#
# Run: 107, exploration: 0.15, score: 162
# Scores: (min: 8, avg: 141.22, max: 395)
#
# Run: 108, exploration: 0.15, score: 154
# Scores: (min: 8, avg: 142.65, max: 395)
#
# Run: 109, exploration: 0.15, score: 162
# Scores: (min: 8, avg: 144.13, max: 395)
#
# Run: 110, exploration: 0.15, score: 338
# Scores: (min: 8, avg: 147.39, max: 395)
#
# Run: 111, exploration: 0.15, score: 147
# Scores: (min: 8, avg: 148.75, max: 395)
#
# Run: 112, exploration: 0.15, score: 225
# Scores: (min: 9, avg: 150.92, max: 395)
#
# Run: 113, exploration: 0.15, score: 212
# Scores: (min: 9, avg: 152.94, max: 395)
#
# Run: 114, exploration: 0.15, score: 247
# Scores: (min: 9, avg: 155.32, max: 395)
#
# Run: 115, exploration: 0.15, score: 13
# Scores: (min: 9, avg: 155.35, max: 395)
#
# Run: 116, exploration: 0.15, score: 13
# Scores: (min: 9, avg: 155.38, max: 395)
#
# Run: 117, exploration: 0.15, score: 212
# Scores: (min: 9, avg: 157.39, max: 395)
#
# Run: 118, exploration: 0.15, score: 163
# Scores: (min: 10, avg: 158.93, max: 395)
#
# Run: 119, exploration: 0.15, score: 16
# Scores: (min: 13, avg: 158.99, max: 395)
#
# Run: 120, exploration: 0.15, score: 172
# Scores: (min: 13, avg: 160.37, max: 395)
#
# Run: 121, exploration: 0.15, score: 34
# Scores: (min: 13, avg: 160.43, max: 395)
#
# Run: 122, exploration: 0.15, score: 139
# Scores: (min: 13, avg: 161.44, max: 395)
#
# Run: 123, exploration: 0.15, score: 190
# Scores: (min: 13, avg: 163.04, max: 395)
#
# Run: 124, exploration: 0.15, score: 183
# Scores: (min: 13, avg: 164.38, max: 395)
#
# Run: 125, exploration: 0.15, score: 32
# Scores: (min: 13, avg: 164.33, max: 395)
#
# Run: 126, exploration: 0.15, score: 317
# Scores: (min: 13, avg: 167.03, max: 395)
#
# Run: 127, exploration: 0.15, score: 15
# Scores: (min: 13, avg: 166.28, max: 395)
#
# Run: 128, exploration: 0.15, score: 166
# Scores: (min: 13, avg: 167.04, max: 395)
#
# Run: 129, exploration: 0.15, score: 82
# Scores: (min: 13, avg: 167.11, max: 395)
#
# Run: 130, exploration: 0.15, score: 63
# Scores: (min: 13, avg: 167.08, max: 395)
#
# Run: 131, exploration: 0.15, score: 175
# Scores: (min: 13, avg: 168.46, max: 395)
#
# Run: 132, exploration: 0.15, score: 175
# Scores: (min: 13, avg: 169.66, max: 395)
#
# Run: 133, exploration: 0.15, score: 170
# Scores: (min: 13, avg: 170.71, max: 395)
#
# Run: 134, exploration: 0.15, score: 172
# Scores: (min: 13, avg: 171.94, max: 395)
#
# Run: 135, exploration: 0.15, score: 87
# Scores: (min: 13, avg: 171.87, max: 395)
#
# Run: 136, exploration: 0.15, score: 156
# Scores: (min: 13, avg: 171.33, max: 395)
#
# Run: 137, exploration: 0.15, score: 174
# Scores: (min: 13, avg: 171.89, max: 395)
#
# Run: 138, exploration: 0.15, score: 197
# Scores: (min: 13, avg: 172.67, max: 395)
#
# Run: 139, exploration: 0.15, score: 36
# Scores: (min: 13, avg: 170.22, max: 395)
#
# Run: 140, exploration: 0.15, score: 217
# Scores: (min: 13, avg: 168.44, max: 385)
#
# Run: 141, exploration: 0.15, score: 106
# Scores: (min: 13, avg: 165.9, max: 385)
#
# Run: 142, exploration: 0.15, score: 51
# Scores: (min: 13, avg: 164.12, max: 385)
#
# Run: 143, exploration: 0.15, score: 108
# Scores: (min: 13, avg: 163.28, max: 385)
#
# Run: 144, exploration: 0.15, score: 262
# Scores: (min: 13, avg: 164.13, max: 385)
#
# Run: 145, exploration: 0.15, score: 74
# Scores: (min: 13, avg: 163.33, max: 385)
#
# Run: 146, exploration: 0.15, score: 207
# Scores: (min: 13, avg: 163.62, max: 385)
#
# Run: 147, exploration: 0.15, score: 128
# Scores: (min: 13, avg: 163.2, max: 385)
#
# Run: 148, exploration: 0.15, score: 238
# Scores: (min: 13, avg: 163.78, max: 385)
#
# Run: 149, exploration: 0.15, score: 200
# Scores: (min: 13, avg: 164.07, max: 385)
#
# Run: 150, exploration: 0.15, score: 175
# Scores: (min: 13, avg: 164.36, max: 385)
#
# Run: 151, exploration: 0.15, score: 201
# Scores: (min: 13, avg: 163.9, max: 385)
#
# Run: 152, exploration: 0.15, score: 217
# Scores: (min: 13, avg: 164.17, max: 385)
#
# Run: 153, exploration: 0.15, score: 61
# Scores: (min: 13, avg: 163.04, max: 385)
#
# Run: 154, exploration: 0.15, score: 245
# Scores: (min: 13, avg: 163.73, max: 385)
#
# Run: 155, exploration: 0.15, score: 161
# Scores: (min: 13, avg: 163.52, max: 385)
#
# Run: 156, exploration: 0.15, score: 193
# Scores: (min: 13, avg: 163.69, max: 385)
#
# Run: 157, exploration: 0.15, score: 121
# Scores: (min: 13, avg: 163.27, max: 385)
#
# Run: 158, exploration: 0.15, score: 12
# Scores: (min: 12, avg: 161.56, max: 385)
#
# Run: 159, exploration: 0.15, score: 10
# Scores: (min: 10, avg: 159.52, max: 385)
#
# Run: 160, exploration: 0.15, score: 48
# Scores: (min: 10, avg: 158.1, max: 385)
#
# Run: 161, exploration: 0.15, score: 261
# Scores: (min: 10, avg: 158.32, max: 385)
#
# Run: 162, exploration: 0.15, score: 133
# Scores: (min: 10, avg: 157.62, max: 385)
#
# Run: 163, exploration: 0.15, score: 147
# Scores: (min: 10, avg: 156.96, max: 385)
#
# Run: 164, exploration: 0.15, score: 117
# Scores: (min: 10, avg: 157.88, max: 385)
#
# Run: 165, exploration: 0.15, score: 12
# Scores: (min: 10, avg: 155.08, max: 385)
#
# Run: 166, exploration: 0.15, score: 184
# Scores: (min: 10, avg: 154.35, max: 385)
#
# Run: 167, exploration: 0.15, score: 205
# Scores: (min: 10, avg: 154.23, max: 385)
#
# Run: 168, exploration: 0.15, score: 142
# Scores: (min: 10, avg: 154.28, max: 385)
#
# Run: 169, exploration: 0.15, score: 312
# Scores: (min: 10, avg: 154.73, max: 385)
#
# Run: 170, exploration: 0.15, score: 143
# Scores: (min: 10, avg: 154.06, max: 385)
#
# Run: 171, exploration: 0.15, score: 266
# Scores: (min: 10, avg: 156.06, max: 385)
#
# Run: 172, exploration: 0.15, score: 235
# Scores: (min: 10, avg: 154.56, max: 383)
#
# Run: 173, exploration: 0.15, score: 100
# Scores: (min: 10, avg: 153.96, max: 383)
#
# Run: 174, exploration: 0.15, score: 328
# Scores: (min: 10, avg: 155.22, max: 383)
#
# Run: 175, exploration: 0.15, score: 221
# Scores: (min: 10, avg: 155.76, max: 383)
#
# Run: 176, exploration: 0.15, score: 225
# Scores: (min: 10, avg: 155.94, max: 383)
#
# Run: 177, exploration: 0.15, score: 178
# Scores: (min: 10, avg: 155.06, max: 383)
#
# Run: 178, exploration: 0.15, score: 211
# Scores: (min: 10, avg: 155.46, max: 383)
#
# Run: 179, exploration: 0.15, score: 153
# Scores: (min: 10, avg: 156.12, max: 383)
#
# Run: 180, exploration: 0.15, score: 284
# Scores: (min: 10, avg: 158.41, max: 383)
#
# Run: 181, exploration: 0.15, score: 133
# Scores: (min: 10, avg: 157.57, max: 383)
#
# Run: 182, exploration: 0.15, score: 43
# Scores: (min: 10, avg: 156.62, max: 383)
#
# Run: 183, exploration: 0.15, score: 203
# Scores: (min: 10, avg: 157.15, max: 383)
#
# Run: 184, exploration: 0.15, score: 29
# Scores: (min: 10, avg: 156.09, max: 383)
#
# Run: 185, exploration: 0.15, score: 105
# Scores: (min: 10, avg: 155.28, max: 383)
#
# Run: 186, exploration: 0.15, score: 161
# Scores: (min: 10, avg: 155.38, max: 383)
#
# Run: 187, exploration: 0.15, score: 170
# Scores: (min: 10, avg: 155.2, max: 383)
#
# Run: 188, exploration: 0.15, score: 131
# Scores: (min: 10, avg: 154.73, max: 383)
#
# Run: 189, exploration: 0.15, score: 165
# Scores: (min: 10, avg: 156.12, max: 383)
#
# Run: 190, exploration: 0.15, score: 19
# Scores: (min: 10, avg: 154.51, max: 383)
#
# Run: 191, exploration: 0.15, score: 15
# Scores: (min: 10, avg: 152.23, max: 383)
#
# Run: 192, exploration: 0.15, score: 135
# Scores: (min: 10, avg: 152.36, max: 383)
#
# Run: 193, exploration: 0.15, score: 214
# Scores: (min: 10, avg: 152.53, max: 383)
# Run: 194, exploration: 0.15, score: 200
# Scores: (min: 10, avg: 152.42, max: 383)
#
# Run: 195, exploration: 0.15, score: 139
# Scores: (min: 10, avg: 152.24, max: 383)
#
# Run: 196, exploration: 0.15, score: 71
# Scores: (min: 10, avg: 152.75, max: 383)
#
# Run: 197, exploration: 0.15, score: 186
# Scores: (min: 10, avg: 154.47, max: 383)
#
# Run: 198, exploration: 0.15, score: 230
# Scores: (min: 10, avg: 155.35, max: 383)
#
# Run: 199, exploration: 0.15, score: 105
# Scores: (min: 10, avg: 154.81, max: 383)
#
# Run: 200, exploration: 0.15, score: 111
# Scores: (min: 10, avg: 155.18, max: 383)
#
# Run: 201, exploration: 0.15, score: 60
# Scores: (min: 10, avg: 154.65, max: 383)
#
# Run: 202, exploration: 0.15, score: 248
# Scores: (min: 10, avg: 155.84, max: 383)
#
# Run: 203, exploration: 0.15, score: 35
# Scores: (min: 10, avg: 154.65, max: 383)
#
# Run: 204, exploration: 0.15, score: 60
# Scores: (min: 10, avg: 151.42, max: 338)
#
# Run: 205, exploration: 0.15, score: 35
# Scores: (min: 10, avg: 149.14, max: 338)
#
# Run: 206, exploration: 0.15, score: 15
# Scores: (min: 10, avg: 147.09, max: 338)
#
# Run: 207, exploration: 0.15, score: 11
# Scores: (min: 10, avg: 145.58, max: 338)
#
# Run: 208, exploration: 0.15, score: 71
# Scores: (min: 10, avg: 144.75, max: 338)
#
# Run: 209, exploration: 0.15, score: 272
# Scores: (min: 10, avg: 145.85, max: 338)
#
# Run: 210, exploration: 0.15, score: 48
# Scores: (min: 10, avg: 142.95, max: 328)
#
# Run: 211, exploration: 0.15, score: 94
# Scores: (min: 10, avg: 142.42, max: 328)
#
# Run: 212, exploration: 0.15, score: 44
# Scores: (min: 10, avg: 140.61, max: 328)
#
# Run: 213, exploration: 0.15, score: 90
# Scores: (min: 10, avg: 139.39, max: 328)
#
# Run: 214, exploration: 0.15, score: 21
# Scores: (min: 10, avg: 137.13, max: 328)
#
# Run: 215, exploration: 0.15, score: 11
# Scores: (min: 10, avg: 137.11, max: 328)
#
# Run: 216, exploration: 0.15, score: 11
# Scores: (min: 10, avg: 137.09, max: 328)
#
# Run: 217, exploration: 0.15, score: 123
# Scores: (min: 10, avg: 136.2, max: 328)
#
# Run: 218, exploration: 0.15, score: 241
# Scores: (min: 10, avg: 136.98, max: 328)
#
# Run: 219, exploration: 0.15, score: 117
# Scores: (min: 10, avg: 137.99, max: 328)
#
# Run: 220, exploration: 0.15, score: 62
# Scores: (min: 10, avg: 136.89, max: 328)
#
# Run: 221, exploration: 0.15, score: 20
# Scores: (min: 10, avg: 136.75, max: 328)
#
# Run: 222, exploration: 0.15, score: 13
# Scores: (min: 10, avg: 135.49, max: 328)
#
# Run: 223, exploration: 0.15, score: 299
# Scores: (min: 10, avg: 136.58, max: 328)
#
# Run: 224, exploration: 0.15, score: 64
# Scores: (min: 10, avg: 135.39, max: 328)
#
# Run: 225, exploration: 0.15, score: 229
# Scores: (min: 10, avg: 137.36, max: 328)
#
# Run: 226, exploration: 0.15, score: 15
# Scores: (min: 10, avg: 134.34, max: 328)
#
# Run: 227, exploration: 0.15, score: 116
# Scores: (min: 10, avg: 135.35, max: 328)
#
# Run: 228, exploration: 0.15, score: 50
# Scores: (min: 10, avg: 134.19, max: 328)
#
# Run: 229, exploration: 0.15, score: 119
# Scores: (min: 10, avg: 134.56, max: 328)
#
# Run: 230, exploration: 0.15, score: 29
# Scores: (min: 10, avg: 134.22, max: 328)
#
# Run: 231, exploration: 0.15, score: 22
# Scores: (min: 10, avg: 132.69, max: 328)
#
# Run: 232, exploration: 0.15, score: 29
# Scores: (min: 10, avg: 131.23, max: 328)
#
# Run: 233, exploration: 0.15, score: 187
# Scores: (min: 10, avg: 131.4, max: 328)
#
# Run: 234, exploration: 0.15, score: 109
# Scores: (min: 10, avg: 130.77, max: 328)
#
# Run: 235, exploration: 0.15, score: 13
# Scores: (min: 10, avg: 130.03, max: 328)
#
# Run: 236, exploration: 0.15, score: 19
# Scores: (min: 10, avg: 128.66, max: 328)
#
# Run: 237, exploration: 0.15, score: 40
# Scores: (min: 10, avg: 127.32, max: 328)
#
# Run: 238, exploration: 0.15, score: 99
# Scores: (min: 10, avg: 126.34, max: 328)
#
# Run: 239, exploration: 0.15, score: 251
# Scores: (min: 10, avg: 128.49, max: 328)
#
# Run: 240, exploration: 0.15, score: 105
# Scores: (min: 10, avg: 127.37, max: 328)
#
# Run: 241, exploration: 0.15, score: 105
# Scores: (min: 10, avg: 127.36, max: 328)
#
# Run: 242, exploration: 0.15, score: 443
# Scores: (min: 10, avg: 131.28, max: 443)
#
# Run: 243, exploration: 0.15, score: 14
# Scores: (min: 10, avg: 130.34, max: 443)
#
# Run: 244, exploration: 0.15, score: 91
# Scores: (min: 10, avg: 128.63, max: 443)
#
# Run: 245, exploration: 0.15, score: 233
# Scores: (min: 10, avg: 130.22, max: 443)
#
# Run: 246, exploration: 0.15, score: 134
# Scores: (min: 10, avg: 129.49, max: 443)
#
# Run: 247, exploration: 0.15, score: 9
# Scores: (min: 9, avg: 128.3, max: 443)
#
# Run: 248, exploration: 0.15, score: 11
# Scores: (min: 9, avg: 126.03, max: 443)
#
# Run: 249, exploration: 0.15, score: 175
# Scores: (min: 9, avg: 125.78, max: 443)
#
# Run: 250, exploration: 0.15, score: 187
# Scores: (min: 9, avg: 125.9, max: 443)
#
# Run: 251, exploration: 0.15, score: 337
# Scores: (min: 9, avg: 127.26, max: 443)
#
# Run: 252, exploration: 0.15, score: 74
# Scores: (min: 9, avg: 125.83, max: 443)
#
# Run: 253, exploration: 0.15, score: 192
# Scores: (min: 9, avg: 127.14, max: 443)
#
# Run: 254, exploration: 0.15, score: 63
# Scores: (min: 9, avg: 125.32, max: 443)
#
# Run: 255, exploration: 0.15, score: 167
# Scores: (min: 9, avg: 125.38, max: 443)
#
# Run: 256, exploration: 0.15, score: 233
# Scores: (min: 9, avg: 125.78, max: 443)
#
# Run: 257, exploration: 0.15, score: 103
# Scores: (min: 9, avg: 125.6, max: 443)
#
# Run: 258, exploration: 0.15, score: 281
# Scores: (min: 9, avg: 128.29, max: 443)
#
# Run: 259, exploration: 0.15, score: 409
# Scores: (min: 9, avg: 132.28, max: 443)
#
# Run: 260, exploration: 0.15, score: 306
# Scores: (min: 9, avg: 134.86, max: 443)
#
# Run: 261, exploration: 0.15, score: 41
# Scores: (min: 9, avg: 132.66, max: 443)
#
# Run: 262, exploration: 0.15, score: 145
# Scores: (min: 9, avg: 132.78, max: 443)
#
# Run: 263, exploration: 0.15, score: 126
# Scores: (min: 9, avg: 132.57, max: 443)
#
# Run: 264, exploration: 0.15, score: 149
# Scores: (min: 9, avg: 132.89, max: 443)
#
# Run: 265, exploration: 0.15, score: 13
# Scores: (min: 9, avg: 132.9, max: 443)
#
# Run: 266, exploration: 0.15, score: 62
# Scores: (min: 9, avg: 131.68, max: 443)
#
# Run: 267, exploration: 0.15, score: 92
# Scores: (min: 9, avg: 130.55, max: 443)
#
# Run: 268, exploration: 0.15, score: 115
# Scores: (min: 9, avg: 130.28, max: 443)
#
# Run: 269, exploration: 0.15, score: 70
# Scores: (min: 9, avg: 127.86, max: 443)
#
# Run: 270, exploration: 0.15, score: 18
# Scores: (min: 9, avg: 126.61, max: 443)
#
# Run: 271, exploration: 0.15, score: 14
# Scores: (min: 9, avg: 124.09, max: 443)
#
# Run: 272, exploration: 0.15, score: 15
# Scores: (min: 9, avg: 121.89, max: 443)
#
# Run: 273, exploration: 0.15, score: 17
# Scores: (min: 9, avg: 121.06, max: 443)
#
# Run: 274, exploration: 0.15, score: 25
# Scores: (min: 9, avg: 118.03, max: 443)
#
# Run: 275, exploration: 0.15, score: 30
# Scores: (min: 9, avg: 116.12, max: 443)
#
# Run: 276, exploration: 0.15, score: 30
# Scores: (min: 9, avg: 114.17, max: 443)
#
# Run: 277, exploration: 0.15, score: 48
# Scores: (min: 9, avg: 112.87, max: 443)
#
# Run: 278, exploration: 0.15, score: 37
# Scores: (min: 9, avg: 111.13, max: 443)
#
# Run: 279, exploration: 0.15, score: 17
# Scores: (min: 9, avg: 109.77, max: 443)
#
# Run: 280, exploration: 0.15, score: 34
# Scores: (min: 9, avg: 107.27, max: 443)
#
# Run: 281, exploration: 0.15, score: 90
# Scores: (min: 9, avg: 106.84, max: 443)
#
# Run: 282, exploration: 0.15, score: 133
# Scores: (min: 9, avg: 107.74, max: 443)
#
# Run: 283, exploration: 0.15, score: 142
# Scores: (min: 9, avg: 107.13, max: 443)
#
# Run: 284, exploration: 0.15, score: 151
# Scores: (min: 9, avg: 108.35, max: 443)
#
# Run: 285, exploration: 0.15, score: 119
# Scores: (min: 9, avg: 108.49, max: 443)
#
# Run: 286, exploration: 0.15, score: 20
# Scores: (min: 9, avg: 107.08, max: 443)
#
# Run: 287, exploration: 0.15, score: 188
# Scores: (min: 9, avg: 107.26, max: 443)
#
# Run: 288, exploration: 0.15, score: 309
# Scores: (min: 9, avg: 109.04, max: 443)
#
# Run: 289, exploration: 0.15, score: 158
# Scores: (min: 9, avg: 108.97, max: 443)
#
# Run: 290, exploration: 0.15, score: 108
# Scores: (min: 9, avg: 109.86, max: 443)
#
# Run: 291, exploration: 0.15, score: 114
# Scores: (min: 9, avg: 110.85, max: 443)
#
# Run: 292, exploration: 0.15, score: 137
# Scores: (min: 9, avg: 110.87, max: 443)
#
# Run: 293, exploration: 0.15, score: 97
# Scores: (min: 9, avg: 109.7, max: 443)
#
# Run: 294, exploration: 0.15, score: 13
# Scores: (min: 9, avg: 107.83, max: 443)
#
# Run: 295, exploration: 0.15, score: 252
# Scores: (min: 9, avg: 108.96, max: 443)
# Run: 296, exploration: 0.15, score: 96
# Scores: (min: 9, avg: 109.21, max: 443)
#
# Run: 297, exploration: 0.15, score: 133
# Scores: (min: 9, avg: 108.68, max: 443)
#
# Run: 298, exploration: 0.15, score: 176
# Scores: (min: 9, avg: 108.14, max: 443)
#
# Run: 299, exploration: 0.15, score: 107
# Scores: (min: 9, avg: 108.16, max: 443)
#
# Run: 300, exploration: 0.15, score: 158
# Scores: (min: 9, avg: 108.63, max: 443)
#
# Run: 301, exploration: 0.15, score: 214
# Scores: (min: 9, avg: 110.17, max: 443)
#
# Run: 302, exploration: 0.15, score: 151
# Scores: (min: 9, avg: 109.2, max: 443)
#
# Run: 303, exploration: 0.15, score: 102
# Scores: (min: 9, avg: 109.87, max: 443)
#
# Run: 304, exploration: 0.15, score: 112
# Scores: (min: 9, avg: 110.39, max: 443)
#
# Run: 305, exploration: 0.15, score: 129
# Scores: (min: 9, avg: 111.33, max: 443)
#
# Run: 306, exploration: 0.15, score: 232
# Scores: (min: 9, avg: 113.5, max: 443)
#
# Run: 307, exploration: 0.15, score: 20
# Scores: (min: 9, avg: 113.59, max: 443)
#
# Run: 308, exploration: 0.15, score: 70
# Scores: (min: 9, avg: 113.58, max: 443)
#
# Run: 309, exploration: 0.15, score: 123
# Scores: (min: 9, avg: 112.09, max: 443)
#
# Run: 310, exploration: 0.15, score: 121
# Scores: (min: 9, avg: 112.82, max: 443)
#
# Run: 311, exploration: 0.15, score: 20
# Scores: (min: 9, avg: 112.08, max: 443)
#
# Run: 312, exploration: 0.15, score: 136
# Scores: (min: 9, avg: 113, max: 443)
#
# Run: 313, exploration: 0.15, score: 128
# Scores: (min: 9, avg: 113.38, max: 443)
#
# Run: 314, exploration: 0.15, score: 151
# Scores: (min: 9, avg: 114.68, max: 443)
#
# Run: 315, exploration: 0.15, score: 122
# Scores: (min: 9, avg: 115.79, max: 443)
#
# Run: 316, exploration: 0.15, score: 86
# Scores: (min: 9, avg: 116.54, max: 443)
#
# Run: 317, exploration: 0.15, score: 40
# Scores: (min: 9, avg: 115.71, max: 443)
#
# Run: 318, exploration: 0.15, score: 310
# Scores: (min: 9, avg: 116.4, max: 443)
#
# Run: 319, exploration: 0.15, score: 18
# Scores: (min: 9, avg: 115.41, max: 443)
#
# Run: 320, exploration: 0.15, score: 34
# Scores: (min: 9, avg: 115.13, max: 443)
#
# Run: 321, exploration: 0.15, score: 164
# Scores: (min: 9, avg: 116.57, max: 443)
#
# Run: 322, exploration: 0.15, score: 291
# Scores: (min: 9, avg: 119.35, max: 443)
#
# Run: 323, exploration: 0.15, score: 163
# Scores: (min: 9, avg: 117.99, max: 443)
#
# Run: 324, exploration: 0.15, score: 69
# Scores: (min: 9, avg: 118.04, max: 443)
#
# Run: 325, exploration: 0.15, score: 94
# Scores: (min: 9, avg: 116.69, max: 443)
#
# Run: 326, exploration: 0.15, score: 182
# Scores: (min: 9, avg: 118.36, max: 443)
#
# Run: 327, exploration: 0.15, score: 139
# Scores: (min: 9, avg: 118.59, max: 443)
#
# Run: 328, exploration: 0.15, score: 18
# Scores: (min: 9, avg: 118.27, max: 443)
#
# Run: 329, exploration: 0.15, score: 10
# Scores: (min: 9, avg: 117.18, max: 443)
#
# Run: 330, exploration: 0.15, score: 11
# Scores: (min: 9, avg: 117, max: 443)
#
# Run: 331, exploration: 0.15, score: 115
# Scores: (min: 9, avg: 117.93, max: 443)
#
# Run: 332, exploration: 0.15, score: 17
# Scores: (min: 9, avg: 117.81, max: 443)
#
# Run: 333, exploration: 0.15, score: 293
# Scores: (min: 9, avg: 118.87, max: 443)
#
# Run: 334, exploration: 0.15, score: 44
# Scores: (min: 9, avg: 118.22, max: 443)
#
# Run: 335, exploration: 0.15, score: 103
# Scores: (min: 9, avg: 119.12, max: 443)
#
# Run: 336, exploration: 0.15, score: 79
# Scores: (min: 9, avg: 119.72, max: 443)
#
# Run: 337, exploration: 0.15, score: 92
# Scores: (min: 9, avg: 120.24, max: 443)
#
# Run: 338, exploration: 0.15, score: 71
# Scores: (min: 9, avg: 119.96, max: 443)
#
# Run: 339, exploration: 0.15, score: 26
# Scores: (min: 9, avg: 117.71, max: 443)
#
# Run: 340, exploration: 0.15, score: 94
# Scores: (min: 9, avg: 117.6, max: 443)
#
# Run: 341, exploration: 0.15, score: 43
# Scores: (min: 9, avg: 116.98, max: 443)
#
# Run: 342, exploration: 0.15, score: 90
# Scores: (min: 9, avg: 113.45, max: 409)
#
# Run: 343, exploration: 0.15, score: 114
# Scores: (min: 9, avg: 114.45, max: 409)
#
# Run: 344, exploration: 0.15, score: 277
# Scores: (min: 9, avg: 116.31, max: 409)
#
# Run: 345, exploration: 0.15, score: 178
# Scores: (min: 9, avg: 115.76, max: 409)
#
# Run: 346, exploration: 0.15, score: 22
# Scores: (min: 9, avg: 114.64, max: 409)
#
# Run: 347, exploration: 0.15, score: 121
# Scores: (min: 10, avg: 115.76, max: 409)
#
# Run: 348, exploration: 0.15, score: 123
# Scores: (min: 10, avg: 116.88, max: 409)
#
# Run: 349, exploration: 0.15, score: 18
# Scores: (min: 10, avg: 115.31, max: 409)
#
# Run: 350, exploration: 0.15, score: 17
# Scores: (min: 10, avg: 113.61, max: 409)
#
# Run: 351, exploration: 0.15, score: 99
# Scores: (min: 10, avg: 111.23, max: 409)
#
# Run: 352, exploration: 0.15, score: 345
# Scores: (min: 10, avg: 113.94, max: 409)
#
# Run: 353, exploration: 0.15, score: 175
# Scores: (min: 10, avg: 113.77, max: 409)
#
# Run: 354, exploration: 0.15, score: 43
# Scores: (min: 10, avg: 113.57, max: 409)
#
# Run: 355, exploration: 0.15, score: 175
# Scores: (min: 10, avg: 113.65, max: 409)
#
# Run: 356, exploration: 0.15, score: 193
# Scores: (min: 10, avg: 113.25, max: 409)
#
# Run: 357, exploration: 0.15, score: 138
# Scores: (min: 10, avg: 113.6, max: 409)
#
# Run: 358, exploration: 0.15, score: 207
# Scores: (min: 10, avg: 112.86, max: 409)
#
# Run: 359, exploration: 0.15, score: 374
# Scores: (min: 10, avg: 112.51, max: 374)
#
# Run: 360, exploration: 0.15, score: 171
# Scores: (min: 10, avg: 111.16, max: 374)
#
# Run: 361, exploration: 0.15, score: 20
# Scores: (min: 10, avg: 110.95, max: 374)
#
# Run: 362, exploration: 0.15, score: 36
# Scores: (min: 10, avg: 109.86, max: 374)
#
# Run: 363, exploration: 0.15, score: 284
# Scores: (min: 10, avg: 111.44, max: 374)
#
# Run: 364, exploration: 0.15, score: 115
# Scores: (min: 10, avg: 111.1, max: 374)
#
# Run: 365, exploration: 0.15, score: 155
# Scores: (min: 10, avg: 112.52, max: 374)
#
# Run: 366, exploration: 0.15, score: 151
# Scores: (min: 10, avg: 113.41, max: 374)
#
# Run: 367, exploration: 0.15, score: 150
# Scores: (min: 10, avg: 113.99, max: 374)
#
# Run: 368, exploration: 0.15, score: 12
# Scores: (min: 10, avg: 112.96, max: 374)
#
# Run: 369, exploration: 0.15, score: 57
# Scores: (min: 10, avg: 112.83, max: 374)
#
# Run: 370, exploration: 0.15, score: 171
# Scores: (min: 10, avg: 114.36, max: 374)
#
# Run: 371, exploration: 0.15, score: 98
# Scores: (min: 10, avg: 115.2, max: 374)
#
# Run: 372, exploration: 0.15, score: 120
# Scores: (min: 10, avg: 116.25, max: 374)
#
# Run: 373, exploration: 0.15, score: 65
# Scores: (min: 10, avg: 116.73, max: 374)
#
# Run: 374, exploration: 0.15, score: 142
# Scores: (min: 10, avg: 117.9, max: 374)
#
# Run: 375, exploration: 0.15, score: 111
# Scores: (min: 10, avg: 118.71, max: 374)
#
# Run: 376, exploration: 0.15, score: 82
# Scores: (min: 10, avg: 119.23, max: 374)
#
# Run: 377, exploration: 0.15, score: 151
# Scores: (min: 10, avg: 120.26, max: 374)
#
# Run: 378, exploration: 0.15, score: 144
# Scores: (min: 10, avg: 121.33, max: 374)
#
# Run: 379, exploration: 0.15, score: 104
# Scores: (min: 10, avg: 122.2, max: 374)
#
# Run: 380, exploration: 0.15, score: 21
# Scores: (min: 10, avg: 122.07, max: 374)
#
# Run: 381, exploration: 0.15, score: 216
# Scores: (min: 10, avg: 123.33, max: 374)
#
# Run: 382, exploration: 0.15, score: 107
# Scores: (min: 10, avg: 123.07, max: 374)
#
# Run: 383, exploration: 0.15, score: 30
# Scores: (min: 10, avg: 121.95, max: 374)
#
# Run: 384, exploration: 0.15, score: 192
# Scores: (min: 10, avg: 122.36, max: 374)
#
# Run: 385, exploration: 0.15, score: 107
# Scores: (min: 10, avg: 122.24, max: 374)
#
# Run: 386, exploration: 0.15, score: 134
# Scores: (min: 10, avg: 123.38, max: 374)
#
# Run: 387, exploration: 0.15, score: 77
# Scores: (min: 10, avg: 122.27, max: 374)
#
# Run: 388, exploration: 0.15, score: 188
# Scores: (min: 10, avg: 121.06, max: 374)
#
# Run: 389, exploration: 0.15, score: 171
# Scores: (min: 10, avg: 121.19, max: 374)
#
# Run: 390, exploration: 0.15, score: 22
# Scores: (min: 10, avg: 120.33, max: 374)
#
# Run: 391, exploration: 0.15, score: 122
# Scores: (min: 10, avg: 120.41, max: 374)
#
# Run: 392, exploration: 0.15, score: 107
# Scores: (min: 10, avg: 120.11, max: 374)
#
# Run: 393, exploration: 0.15, score: 168
# Scores: (min: 10, avg: 120.82, max: 374)
#
# Run: 394, exploration: 0.15, score: 109
# Scores: (min: 10, avg: 121.78, max: 374)
#
# Run: 395, exploration: 0.15, score: 56
# Scores: (min: 10, avg: 119.82, max: 374)
#
# Run: 396, exploration: 0.15, score: 55
# Scores: (min: 10, avg: 119.41, max: 374)
#
# Run: 397, exploration: 0.15, score: 94
# Scores: (min: 10, avg: 119.02, max: 374)
# Run: 398, exploration: 0.15, score: 103
# Scores: (min: 10, avg: 118.29, max: 374)
#
# Run: 399, exploration: 0.15, score: 33
# Scores: (min: 10, avg: 117.55, max: 374)
#
# Run: 400, exploration: 0.15, score: 30
# Scores: (min: 10, avg: 116.27, max: 374)
#
# Run: 401, exploration: 0.15, score: 31
# Scores: (min: 10, avg: 114.44, max: 374)
#
# Run: 402, exploration: 0.15, score: 19
# Scores: (min: 10, avg: 113.12, max: 374)
#
# Run: 403, exploration: 0.15, score: 78
# Scores: (min: 10, avg: 112.88, max: 374)
#
# Run: 404, exploration: 0.15, score: 44
# Scores: (min: 10, avg: 112.2, max: 374)
#
# Run: 405, exploration: 0.15, score: 82
# Scores: (min: 10, avg: 111.73, max: 374)
#
# Run: 406, exploration: 0.15, score: 83
# Scores: (min: 10, avg: 110.24, max: 374)
#
# Run: 407, exploration: 0.15, score: 75
# Scores: (min: 10, avg: 110.79, max: 374)
#
# Run: 408, exploration: 0.15, score: 22
# Scores: (min: 10, avg: 110.31, max: 374)
#
# Run: 409, exploration: 0.15, score: 110
# Scores: (min: 10, avg: 110.18, max: 374)
#
# Run: 410, exploration: 0.15, score: 166
# Scores: (min: 10, avg: 110.63, max: 374)
#
# Run: 411, exploration: 0.15, score: 49
# Scores: (min: 10, avg: 110.92, max: 374)
#
# Run: 412, exploration: 0.15, score: 135
# Scores: (min: 10, avg: 110.91, max: 374)
#
# Run: 413, exploration: 0.15, score: 125
# Scores: (min: 10, avg: 110.88, max: 374)
#
# Run: 414, exploration: 0.15, score: 221
# Scores: (min: 10, avg: 111.58, max: 374)
#
# Run: 415, exploration: 0.15, score: 124
# Scores: (min: 10, avg: 111.6, max: 374)
#
# Run: 416, exploration: 0.15, score: 99
# Scores: (min: 10, avg: 111.73, max: 374)
#
# Run: 417, exploration: 0.15, score: 165
# Scores: (min: 10, avg: 112.98, max: 374)
#
# Run: 418, exploration: 0.15, score: 46
# Scores: (min: 10, avg: 110.34, max: 374)
#
# Run: 419, exploration: 0.15, score: 200
# Scores: (min: 10, avg: 112.16, max: 374)
#
# Run: 420, exploration: 0.15, score: 168
# Scores: (min: 10, avg: 113.5, max: 374)
#
# Run: 421, exploration: 0.15, score: 153
# Scores: (min: 10, avg: 113.39, max: 374)
#
# Run: 422, exploration: 0.15, score: 16
# Scores: (min: 10, avg: 110.64, max: 374)
#
# Run: 423, exploration: 0.15, score: 349
# Scores: (min: 10, avg: 112.5, max: 374)
#
# Run: 424, exploration: 0.15, score: 145
# Scores: (min: 10, avg: 113.26, max: 374)
#
# Run: 425, exploration: 0.15, score: 161
# Scores: (min: 10, avg: 113.93, max: 374)
#
# Run: 426, exploration: 0.15, score: 213
# Scores: (min: 10, avg: 114.24, max: 374)
#
# Run: 427, exploration: 0.15, score: 164
# Scores: (min: 10, avg: 114.49, max: 374)
#
# Run: 428, exploration: 0.15, score: 120
# Scores: (min: 10, avg: 115.51, max: 374)
#
# Run: 429, exploration: 0.15, score: 141
# Scores: (min: 11, avg: 116.82, max: 374)
#
# Run: 430, exploration: 0.15, score: 189
# Scores: (min: 12, avg: 118.6, max: 374)
#
# Run: 431, exploration: 0.15, score: 10
# Scores: (min: 10, avg: 117.55, max: 374)
#
# Run: 432, exploration: 0.15, score: 109
# Scores: (min: 10, avg: 118.47, max: 374)
#
# Run: 433, exploration: 0.15, score: 162
# Scores: (min: 10, avg: 117.16, max: 374)
#
# Run: 434, exploration: 0.15, score: 68
# Scores: (min: 10, avg: 117.4, max: 374)
#
# Run: 435, exploration: 0.15, score: 20
# Scores: (min: 10, avg: 116.57, max: 374)
#
# Run: 436, exploration: 0.15, score: 36
# Scores: (min: 10, avg: 116.14, max: 374)
#
# Run: 437, exploration: 0.15, score: 24
# Scores: (min: 10, avg: 115.46, max: 374)
#
# Run: 438, exploration: 0.15, score: 33
# Scores: (min: 10, avg: 115.08, max: 374)
#
# Run: 439, exploration: 0.15, score: 34
# Scores: (min: 10, avg: 115.16, max: 374)
#
# Run: 440, exploration: 0.15, score: 19
# Scores: (min: 10, avg: 114.41, max: 374)
#
# Run: 441, exploration: 0.15, score: 137
# Scores: (min: 10, avg: 115.35, max: 374)
#
# Run: 442, exploration: 0.15, score: 62
# Scores: (min: 10, avg: 115.07, max: 374)
#
# Run: 443, exploration: 0.15, score: 63
# Scores: (min: 10, avg: 114.56, max: 374)
#
# Run: 444, exploration: 0.15, score: 159
# Scores: (min: 10, avg: 113.38, max: 374)
#
# Run: 445, exploration: 0.15, score: 130
# Scores: (min: 10, avg: 112.9, max: 374)
#
# Run: 446, exploration: 0.15, score: 52
# Scores: (min: 10, avg: 113.2, max: 374)
#
# Run: 447, exploration: 0.15, score: 262
# Scores: (min: 10, avg: 114.61, max: 374)
#
# Run: 448, exploration: 0.15, score: 158
# Scores: (min: 10, avg: 114.96, max: 374)
#
# Run: 449, exploration: 0.15, score: 129
# Scores: (min: 10, avg: 116.07, max: 374)
#
# Run: 450, exploration: 0.15, score: 207
# Scores: (min: 10, avg: 117.97, max: 374)
#
# Run: 451, exploration: 0.15, score: 144
# Scores: (min: 10, avg: 118.42, max: 374)
#
# Run: 452, exploration: 0.15, score: 17
# Scores: (min: 10, avg: 115.14, max: 374)
#
# Run: 453, exploration: 0.15, score: 93
# Scores: (min: 10, avg: 114.32, max: 374)
#
# Run: 454, exploration: 0.15, score: 126
# Scores: (min: 10, avg: 115.15, max: 374)
#
# Run: 455, exploration: 0.15, score: 127
# Scores: (min: 10, avg: 114.67, max: 374)
#
# Run: 456, exploration: 0.15, score: 169
# Scores: (min: 10, avg: 114.43, max: 374)
#
# Run: 457, exploration: 0.15, score: 107
# Scores: (min: 10, avg: 114.12, max: 374)
#
# Run: 458, exploration: 0.15, score: 29
# Scores: (min: 10, avg: 112.34, max: 374)
#
# Run: 459, exploration: 0.15, score: 93
# Scores: (min: 10, avg: 109.53, max: 349)
#
# Run: 460, exploration: 0.15, score: 106
# Scores: (min: 10, avg: 108.88, max: 349)
#
# Run: 461, exploration: 0.15, score: 94
# Scores: (min: 10, avg: 109.62, max: 349)
#
# Run: 462, exploration: 0.15, score: 170
# Scores: (min: 10, avg: 110.96, max: 349)
#
# Run: 463, exploration: 0.15, score: 16
# Scores: (min: 10, avg: 108.28, max: 349)
#
# Run: 464, exploration: 0.15, score: 77
# Scores: (min: 10, avg: 107.9, max: 349)
#
# Run: 465, exploration: 0.15, score: 263
# Scores: (min: 10, avg: 108.98, max: 349)
#
# Run: 466, exploration: 0.15, score: 80
# Scores: (min: 10, avg: 108.27, max: 349)
#
# Run: 467, exploration: 0.15, score: 80
# Scores: (min: 10, avg: 107.57, max: 349)
#
# Run: 468, exploration: 0.15, score: 10
# Scores: (min: 10, avg: 107.55, max: 349)
#
# Run: 469, exploration: 0.15, score: 330
# Scores: (min: 10, avg: 110.28, max: 349)
#
# Run: 470, exploration: 0.15, score: 184
# Scores: (min: 10, avg: 110.41, max: 349)
#
# Run: 471, exploration: 0.15, score: 23
# Scores: (min: 10, avg: 109.66, max: 349)
#
# Run: 472, exploration: 0.15, score: 99
# Scores: (min: 10, avg: 109.45, max: 349)
#
# Run: 473, exploration: 0.15, score: 171
# Scores: (min: 10, avg: 110.51, max: 349)
#
# Run: 474, exploration: 0.15, score: 303
# Scores: (min: 10, avg: 112.12, max: 349)
#
# Run: 475, exploration: 0.15, score: 176
# Scores: (min: 10, avg: 112.77, max: 349)
#
# Run: 476, exploration: 0.15, score: 101
# Scores: (min: 10, avg: 112.96, max: 349)
#
# Run: 477, exploration: 0.15, score: 121
# Scores: (min: 10, avg: 112.66, max: 349)
#
# Run: 478, exploration: 0.15, score: 120
# Scores: (min: 10, avg: 112.42, max: 349)
#
# Run: 479, exploration: 0.15, score: 39
# Scores: (min: 10, avg: 111.77, max: 349)
#
# Run: 480, exploration: 0.15, score: 29
# Scores: (min: 10, avg: 111.85, max: 349)
#
# Run: 481, exploration: 0.15, score: 314
# Scores: (min: 10, avg: 112.83, max: 349)
#
# Run: 482, exploration: 0.15, score: 96
# Scores: (min: 10, avg: 112.72, max: 349)
#
# Run: 483, exploration: 0.15, score: 205
# Scores: (min: 10, avg: 114.47, max: 349)
#
# Run: 484, exploration: 0.15, score: 219
# Scores: (min: 10, avg: 114.74, max: 349)
#
# Run: 485, exploration: 0.15, score: 24
# Scores: (min: 10, avg: 113.91, max: 349)
#
# Run: 486, exploration: 0.15, score: 16
# Scores: (min: 10, avg: 112.73, max: 349)
#
# Run: 487, exploration: 0.15, score: 32
# Scores: (min: 10, avg: 112.28, max: 349)
#
# Run: 488, exploration: 0.15, score: 17
# Scores: (min: 10, avg: 110.57, max: 349)
#
# Run: 489, exploration: 0.15, score: 14
# Scores: (min: 10, avg: 109, max: 349)
#
# Run: 490, exploration: 0.15, score: 18
# Scores: (min: 10, avg: 108.96, max: 349)
#
# Run: 491, exploration: 0.15, score: 11
# Scores: (min: 10, avg: 107.85, max: 349)
#
# Run: 492, exploration: 0.15, score: 15
# Scores: (min: 10, avg: 106.93, max: 349)
#
# Run: 493, exploration: 0.15, score: 309
# Scores: (min: 10, avg: 108.34, max: 349)
#
# Run: 494, exploration: 0.15, score: 147
# Scores: (min: 10, avg: 108.72, max: 349)
#
# Run: 495, exploration: 0.15, score: 114
# Scores: (min: 10, avg: 109.3, max: 349)
#
# Run: 496, exploration: 0.15, score: 162
# Scores: (min: 10, avg: 110.37, max: 349)
#
# Run: 497, exploration: 0.15, score: 346
# Scores: (min: 10, avg: 112.89, max: 349)
#
# Run: 498, exploration: 0.15, score: 12
# Scores: (min: 10, avg: 111.98, max: 349)
# Run: 499, exploration: 0.15, score: 64
# Scores: (min: 10, avg: 112.29, max: 349)
#
# Run: 500, exploration: 0.15, score: 12
# Scores: (min: 10, avg: 112.11, max: 349)
#
# Run: 501, exploration: 0.15, score: 134
# Scores: (min: 10, avg: 113.14, max: 349)
#
# Run: 502, exploration: 0.15, score: 70
# Scores: (min: 10, avg: 113.65, max: 349)
#
# Run: 503, exploration: 0.15, score: 99
# Scores: (min: 10, avg: 113.86, max: 349)
#
# Run: 504, exploration: 0.15, score: 38
# Scores: (min: 10, avg: 113.8, max: 349)
#
# Run: 505, exploration: 0.15, score: 12
# Scores: (min: 10, avg: 113.1, max: 349)
#
# Run: 506, exploration: 0.15, score: 12
# Scores: (min: 10, avg: 112.39, max: 349)
#
# Run: 507, exploration: 0.15, score: 70
# Scores: (min: 10, avg: 112.34, max: 349)
#
# Run: 508, exploration: 0.15, score: 342
# Scores: (min: 10, avg: 115.54, max: 349)
#
# Run: 509, exploration: 0.15, score: 357
# Scores: (min: 10, avg: 118.01, max: 357)
#
# Run: 510, exploration: 0.15, score: 158
# Scores: (min: 10, avg: 117.93, max: 357)
#
# Run: 511, exploration: 0.15, score: 186
# Scores: (min: 10, avg: 119.3, max: 357)
#
# Run: 512, exploration: 0.15, score: 211
# Scores: (min: 10, avg: 120.06, max: 357)
#
# Run: 513, exploration: 0.15, score: 94
# Scores: (min: 10, avg: 119.75, max: 357)
#
# Run: 514, exploration: 0.15, score: 92
# Scores: (min: 10, avg: 118.46, max: 357)
#
# Run: 515, exploration: 0.15, score: 32
# Scores: (min: 10, avg: 117.54, max: 357)
#
# Run: 516, exploration: 0.15, score: 264
# Scores: (min: 10, avg: 119.19, max: 357)
#
# Run: 517, exploration: 0.15, score: 98
# Scores: (min: 10, avg: 118.52, max: 357)
#
# Run: 518, exploration: 0.15, score: 224
# Scores: (min: 10, avg: 120.3, max: 357)
#
# Run: 519, exploration: 0.15, score: 42
# Scores: (min: 10, avg: 118.72, max: 357)
#
# Run: 520, exploration: 0.15, score: 113
# Scores: (min: 10, avg: 118.17, max: 357)
#
# Run: 521, exploration: 0.15, score: 23
# Scores: (min: 10, avg: 116.87, max: 357)
#
# Run: 522, exploration: 0.15, score: 14
# Scores: (min: 10, avg: 116.85, max: 357)
#
# Run: 523, exploration: 0.15, score: 22
# Scores: (min: 10, avg: 113.58, max: 357)
#
# Run: 524, exploration: 0.15, score: 16
# Scores: (min: 10, avg: 112.29, max: 357)
#
# Run: 525, exploration: 0.15, score: 115
# Scores: (min: 10, avg: 111.83, max: 357)
#
# Run: 526, exploration: 0.15, score: 142
# Scores: (min: 10, avg: 111.12, max: 357)
#
# Run: 527, exploration: 0.15, score: 67
# Scores: (min: 10, avg: 110.15, max: 357)
#
# Run: 528, exploration: 0.15, score: 120
# Scores: (min: 10, avg: 110.15, max: 357)
#
# Run: 529, exploration: 0.15, score: 16
# Scores: (min: 10, avg: 108.9, max: 357)
#
# Run: 530, exploration: 0.15, score: 22
# Scores: (min: 10, avg: 107.23, max: 357)
#
# Run: 531, exploration: 0.15, score: 36
# Scores: (min: 10, avg: 107.49, max: 357)
#
# Run: 532, exploration: 0.15, score: 41
# Scores: (min: 10, avg: 106.81, max: 357)
#
# Run: 533, exploration: 0.15, score: 154
# Scores: (min: 10, avg: 106.73, max: 357)
#
# Run: 534, exploration: 0.15, score: 53
# Scores: (min: 10, avg: 106.58, max: 357)
#
# Run: 535, exploration: 0.15, score: 27
# Scores: (min: 10, avg: 106.65, max: 357)
#
# Run: 536, exploration: 0.15, score: 27
# Scores: (min: 10, avg: 106.56, max: 357)
#
# Run: 537, exploration: 0.15, score: 34
# Scores: (min: 10, avg: 106.66, max: 357)
#
# Run: 538, exploration: 0.15, score: 10
# Scores: (min: 10, avg: 106.43, max: 357)
#
# Run: 539, exploration: 0.15, score: 172
# Scores: (min: 10, avg: 107.81, max: 357)
#
# Run: 540, exploration: 0.15, score: 116
# Scores: (min: 10, avg: 108.78, max: 357)
#
# Run: 541, exploration: 0.15, score: 101
# Scores: (min: 10, avg: 108.42, max: 357)
#
# Run: 542, exploration: 0.15, score: 470
# Scores: (min: 10, avg: 112.5, max: 470)
#
# Run: 543, exploration: 0.15, score: 153
# Scores: (min: 10, avg: 113.4, max: 470)
#
# Run: 544, exploration: 0.15, score: 121
# Scores: (min: 10, avg: 113.02, max: 470)
#
# Run: 545, exploration: 0.15, score: 413
# Scores: (min: 10, avg: 115.85, max: 470)
#
# Run: 546, exploration: 0.15, score: 119
# Scores: (min: 10, avg: 116.52, max: 470)
#
# Run: 547, exploration: 0.15, score: 12
# Scores: (min: 10, avg: 114.02, max: 470)
#
# Run: 548, exploration: 0.15, score: 8
# Scores: (min: 8, avg: 112.52, max: 470)
#
# Run: 549, exploration: 0.15, score: 50
# Scores: (min: 8, avg: 111.73, max: 470)
#
# Run: 550, exploration: 0.15, score: 41
# Scores: (min: 8, avg: 110.07, max: 470)
#
# Run: 551, exploration: 0.15, score: 13
# Scores: (min: 8, avg: 108.76, max: 470)
#
# Run: 552, exploration: 0.15, score: 19
# Scores: (min: 8, avg: 108.78, max: 470)
#
# Run: 553, exploration: 0.15, score: 10
# Scores: (min: 8, avg: 107.95, max: 470)
#
# Run: 554, exploration: 0.15, score: 51
# Scores: (min: 8, avg: 107.2, max: 470)
#
# Run: 555, exploration: 0.15, score: 311
# Scores: (min: 8, avg: 109.04, max: 470)
#
# Run: 556, exploration: 0.15, score: 55
# Scores: (min: 8, avg: 107.9, max: 470)
#
# Run: 557, exploration: 0.15, score: 111
# Scores: (min: 8, avg: 107.94, max: 470)
#
# Run: 558, exploration: 0.15, score: 12
# Scores: (min: 8, avg: 107.77, max: 470)
#
# Run: 559, exploration: 0.15, score: 500
# Scores: (min: 8, avg: 111.84, max: 500)
#
# Run: 560, exploration: 0.15, score: 178
# Scores: (min: 8, avg: 112.56, max: 500)
#
# Run: 561, exploration: 0.15, score: 94
# Scores: (min: 8, avg: 112.56, max: 500)
#
# Run: 562, exploration: 0.15, score: 101
# Scores: (min: 8, avg: 111.87, max: 500)
#
# Run: 563, exploration: 0.15, score: 141
# Scores: (min: 8, avg: 113.12, max: 500)
#
# Run: 564, exploration: 0.15, score: 113
# Scores: (min: 8, avg: 113.48, max: 500)
#
# Run: 565, exploration: 0.15, score: 96
# Scores: (min: 8, avg: 111.81, max: 500)
#
# Run: 566, exploration: 0.15, score: 128
# Scores: (min: 8, avg: 112.29, max: 500)
#
# Run: 567, exploration: 0.15, score: 138
# Scores: (min: 8, avg: 112.87, max: 500)
#
# Run: 568, exploration: 0.15, score: 145
# Scores: (min: 8, avg: 114.22, max: 500)
#
# Run: 569, exploration: 0.15, score: 298
# Scores: (min: 8, avg: 113.9, max: 500)
#
# Run: 570, exploration: 0.15, score: 39
# Scores: (min: 8, avg: 112.45, max: 500)
#
# Run: 571, exploration: 0.15, score: 92
# Scores: (min: 8, avg: 113.14, max: 500)
#
# Run: 572, exploration: 0.15, score: 118
# Scores: (min: 8, avg: 113.33, max: 500)
#
# Run: 573, exploration: 0.15, score: 107
# Scores: (min: 8, avg: 112.69, max: 500)
#
# Run: 574, exploration: 0.15, score: 117
# Scores: (min: 8, avg: 110.83, max: 500)
#
# Run: 575, exploration: 0.15, score: 66
# Scores: (min: 8, avg: 109.73, max: 500)
#
# Run: 576, exploration: 0.15, score: 14
# Scores: (min: 8, avg: 108.86, max: 500)
#
# Run: 577, exploration: 0.15, score: 192
# Scores: (min: 8, avg: 109.57, max: 500)
#
# Run: 578, exploration: 0.15, score: 12
# Scores: (min: 8, avg: 108.49, max: 500)
#
# Run: 579, exploration: 0.15, score: 134
# Scores: (min: 8, avg: 109.44, max: 500)
#
# Run: 580, exploration: 0.15, score: 35
# Scores: (min: 8, avg: 109.5, max: 500)
#
# Run: 581, exploration: 0.15, score: 65
# Scores: (min: 8, avg: 107.01, max: 500)
#
# Run: 582, exploration: 0.15, score: 129
# Scores: (min: 8, avg: 107.34, max: 500)
#
# ...
# Scores: (min: 9, avg: 137.67, max: 500)
#
# Run: 1528, exploration: 0.15, score: 19
# Scores: (min: 9, avg: 137.17, max: 500)
#
# Run: 1529, exploration: 0.15, score: 229
# Scores: (min: 9, avg: 137.15, max: 500)
#
# Run: 1530, exploration: 0.15, score: 133
# Scores: (min: 9, avg: 137.23, max: 500)
#
# Run: 1531, exploration: 0.15, score: 48
# Scores: (min: 9, avg: 136.76, max: 500)
#
# Run: 1532, exploration: 0.15, score: 65
# Scores: (min: 9, avg: 135.12, max: 500)
#
# Run: 1533, exploration: 0.15, score: 94
# Scores: (min: 9, avg: 135.17, max: 500)
#
# Run: 1534, exploration: 0.15, score: 19
# Scores: (min: 9, avg: 134.99, max: 500)
#
# Run: 1535, exploration: 0.15, score: 88
# Scores: (min: 9, avg: 135.74, max: 500)
#
# Run: 1536, exploration: 0.15, score: 41
# Scores: (min: 9, avg: 134.84, max: 500)
#
# Run: 1537, exploration: 0.15, score: 73
# Scores: (min: 9, avg: 130.57, max: 500)
#
# Run: 1538, exploration: 0.15, score: 27
# Scores: (min: 9, avg: 130.7, max: 500)
#
# Run: 1539, exploration: 0.15, score: 84
# Scores: (min: 9, avg: 131.38, max: 500)
#
# Run: 1540, exploration: 0.15, score: 88
# Scores: (min: 9, avg: 132.16, max: 500)
#
# Run: 1541, exploration: 0.15, score: 46
# Scores: (min: 14, avg: 132.53, max: 500)
#
# Run: 1542, exploration: 0.15, score: 22
# Scores: (min: 14, avg: 131.72, max: 500)
#
# Run: 1543, exploration: 0.15, score: 107
# Scores: (min: 14, avg: 132.11, max: 500)
#
# Run: 1544, exploration: 0.15, score: 116
# Scores: (min: 14, avg: 131.63, max: 500)
#
# Run: 1545, exploration: 0.15, score: 35
# Scores: (min: 14, avg: 130.84, max: 500)
#
# Run: 1546, exploration: 0.15, score: 262
# Scores: (min: 14, avg: 130.22, max: 500)
#
# Run: 1547, exploration: 0.15, score: 73
# Scores: (min: 14, avg: 128.04, max: 500)
#
# Run: 1548, exploration: 0.15, score: 107
# Scores: (min: 14, avg: 128.13, max: 500)
#
# Run: 1549, exploration: 0.15, score: 10
# Scores: (min: 10, avg: 126.28, max: 500)
#
# Run: 1550, exploration: 0.15, score: 107
# Scores: (min: 10, avg: 125.74, max: 500)
#
# Run: 1551, exploration: 0.15, score: 44
# Scores: (min: 10, avg: 121.18, max: 500)
#
# Run: 1552, exploration: 0.15, score: 19
# Scores: (min: 10, avg: 120.36, max: 500)
#
# Run: 1553, exploration: 0.15, score: 97
# Scores: (min: 10, avg: 117.75, max: 500)
#
# Run: 1554, exploration: 0.15, score: 70
# Scores: (min: 10, avg: 116.17, max: 500)
#
# Run: 1555, exploration: 0.15, score: 343
# Scores: (min: 10, avg: 116.24, max: 500)
#
# Run: 1556, exploration: 0.15, score: 190
# Scores: (min: 10, avg: 116.64, max: 500)
#
# Run: 1557, exploration: 0.15, score: 59
# Scores: (min: 10, avg: 117, max: 500)
#
# Run: 1558, exploration: 0.15, score: 45
# Scores: (min: 10, avg: 113.93, max: 500)
#
# Run: 1559, exploration: 0.15, score: 62
# Scores: (min: 10, avg: 113.07, max: 500)
#
# Run: 1560, exploration: 0.15, score: 21
# Scores: (min: 10, avg: 108.28, max: 433)
#
# Run: 1561, exploration: 0.15, score: 91
# Scores: (min: 10, avg: 106.77, max: 433)
#
# Run: 1562, exploration: 0.15, score: 308
# Scores: (min: 10, avg: 108.62, max: 433)
#
# Run: 1563, exploration: 0.15, score: 142
# Scores: (min: 10, avg: 108.72, max: 433)
#
# Run: 1564, exploration: 0.15, score: 166
# Scores: (min: 10, avg: 109.3, max: 433)
#
# Run: 1565, exploration: 0.15, score: 104
# Scores: (min: 10, avg: 109.58, max: 433)
#
# Run: 1566, exploration: 0.15, score: 157
# Scores: (min: 10, avg: 110.08, max: 433)
#
# Run: 1567, exploration: 0.15, score: 103
# Scores: (min: 10, avg: 110.88, max: 433)
#
# Run: 1568, exploration: 0.15, score: 329
# Scores: (min: 10, avg: 112.22, max: 433)
#
# Run: 1569, exploration: 0.15, score: 57
# Scores: (min: 10, avg: 111.81, max: 433)
#
# Run: 1570, exploration: 0.15, score: 130
# Scores: (min: 10, avg: 111.78, max: 433)
#
# Run: 1571, exploration: 0.15, score: 94
# Scores: (min: 10, avg: 111.37, max: 433)
#
# Run: 1572, exploration: 0.15, score: 500
# Scores: (min: 10, avg: 116.06, max: 500)
#
# Run: 1573, exploration: 0.15, score: 104
# Scores: (min: 10, avg: 116.02, max: 500)
#
# Run: 1574, exploration: 0.15, score: 302
# Scores: (min: 10, avg: 118.79, max: 500)
#
# Run: 1575, exploration: 0.15, score: 26
# Scores: (min: 10, avg: 118.89, max: 500)
#
# Run: 1576, exploration: 0.15, score: 91
# Scores: (min: 10, avg: 118.35, max: 500)
#
# Run: 1577, exploration: 0.15, score: 13
# Scores: (min: 10, avg: 116.87, max: 500)
#
# Run: 1578, exploration: 0.15, score: 94
# Scores: (min: 10, avg: 113.48, max: 500)
#
# Run: 1579, exploration: 0.15, score: 130
# Scores: (min: 10, avg: 113.11, max: 500)
#
# Run: 1580, exploration: 0.15, score: 98
# Scores: (min: 10, avg: 112.68, max: 500)
#
# Run: 1581, exploration: 0.15, score: 27
# Scores: (min: 10, avg: 111.65, max: 500)
#
# Run: 1582, exploration: 0.15, score: 106
# Scores: (min: 10, avg: 111.65, max: 500)
#
# Run: 1583, exploration: 0.15, score: 137
# Scores: (min: 10, avg: 111.68, max: 500)
#
# Run: 1584, exploration: 0.15, score: 119
# Scores: (min: 10, avg: 111.09, max: 500)
#
# Run: 1585, exploration: 0.15, score: 28
# Scores: (min: 10, avg: 110.21, max: 500)
#
# Run: 1586, exploration: 0.15, score: 15
# Scores: (min: 10, avg: 109.41, max: 500)
#
# Run: 1587, exploration: 0.15, score: 26
# Scores: (min: 10, avg: 106.56, max: 500)
#
# Run: 1588, exploration: 0.15, score: 213
# Scores: (min: 10, avg: 107.52, max: 500)
#
# Run: 1589, exploration: 0.15, score: 89
# Scores: (min: 10, avg: 108.24, max: 500)
#
# Run: 1590, exploration: 0.15, score: 96
# Scores: (min: 10, avg: 108.58, max: 500)
#
# Run: 1591, exploration: 0.15, score: 88
# Scores: (min: 10, avg: 106.01, max: 500)
#
# Run: 1592, exploration: 0.15, score: 12
# Scores: (min: 10, avg: 105.15, max: 500)
#
# Run: 1593, exploration: 0.15, score: 90
# Scores: (min: 10, avg: 104.92, max: 500)
#
# Run: 1594, exploration: 0.15, score: 15
# Scores: (min: 10, avg: 104.11, max: 500)
#
# Run: 1595, exploration: 0.15, score: 81
# Scores: (min: 10, avg: 104.46, max: 500)
#
# Run: 1596, exploration: 0.15, score: 372
# Scores: (min: 10, avg: 107.79, max: 500)
#
# Run: 1597, exploration: 0.15, score: 57
# Scores: (min: 10, avg: 108.22, max: 500)
#
# Run: 1598, exploration: 0.15, score: 162
# Scores: (min: 10, avg: 109.2, max: 500)
#
# Run: 1599, exploration: 0.15, score: 165
# Scores: (min: 10, avg: 109.58, max: 500)
#
# Run: 1600, exploration: 0.15, score: 93
# Scores: (min: 10, avg: 109.27, max: 500)
#
# Run: 1601, exploration: 0.15, score: 83
# Scores: (min: 10, avg: 106.97, max: 500)
#
# Run: 1602, exploration: 0.15, score: 160
# Scores: (min: 10, avg: 107.92, max: 500)
#
# Run: 1603, exploration: 0.15, score: 11
# Scores: (min: 10, avg: 106.75, max: 500)
#
# Run: 1604, exploration: 0.15, score: 18
# Scores: (min: 10, avg: 105.42, max: 500)
#
# Run: 1605, exploration: 0.15, score: 155
# Scores: (min: 10, avg: 106.03, max: 500)
#
# Run: 1606, exploration: 0.15, score: 38
# Scores: (min: 10, avg: 106.05, max: 500)
#
# Run: 1607, exploration: 0.15, score: 26
# Scores: (min: 10, avg: 105.16, max: 500)
#
# Run: 1608, exploration: 0.15, score: 17
# Scores: (min: 10, avg: 105.15, max: 500)
#
# Run: 1609, exploration: 0.15, score: 165
# Scores: (min: 10, avg: 106.66, max: 500)
#
# Run: 1610, exploration: 0.15, score: 110
# Scores: (min: 10, avg: 106.51, max: 500)
# Run: 1611, exploration: 0.15, score: 52
# Scores: (min: 10, avg: 105.79, max: 500)
#
# Run: 1612, exploration: 0.15, score: 55
# Scores: (min: 10, avg: 105.86, max: 500)
#
# Run: 1613, exploration: 0.15, score: 47
# Scores: (min: 10, avg: 105.53, max: 500)
#
# Run: 1614, exploration: 0.15, score: 73
# Scores: (min: 10, avg: 105.44, max: 500)
#
# Run: 1615, exploration: 0.15, score: 29
# Scores: (min: 10, avg: 103.71, max: 500)
#
# Run: 1616, exploration: 0.15, score: 37
# Scores: (min: 10, avg: 103.11, max: 500)
#
# Run: 1617, exploration: 0.15, score: 13
# Scores: (min: 10, avg: 103.1, max: 500)
#
# Run: 1618, exploration: 0.15, score: 162
# Scores: (min: 10, avg: 102.96, max: 500)
#
# Run: 1619, exploration: 0.15, score: 139
# Scores: (min: 10, avg: 102.77, max: 500)
#
# Run: 1620, exploration: 0.15, score: 88
# Scores: (min: 10, avg: 102.77, max: 500)
#
# Run: 1621, exploration: 0.15, score: 128
# Scores: (min: 10, avg: 103.28, max: 500)
#
# Run: 1622, exploration: 0.15, score: 102
# Scores: (min: 10, avg: 101, max: 500)
#
# Run: 1623, exploration: 0.15, score: 167
# Scores: (min: 10, avg: 102.53, max: 500)
#
# Run: 1624, exploration: 0.15, score: 101
# Scores: (min: 10, avg: 102.45, max: 500)
#
# Run: 1625, exploration: 0.15, score: 242
# Scores: (min: 10, avg: 103.17, max: 500)
#
# Run: 1626, exploration: 0.15, score: 17
# Scores: (min: 10, avg: 102.43, max: 500)
#
# Run: 1627, exploration: 0.15, score: 289
# Scores: (min: 10, avg: 103.97, max: 500)
#
# Run: 1628, exploration: 0.15, score: 72
# Scores: (min: 10, avg: 104.5, max: 500)
#
# Run: 1629, exploration: 0.15, score: 115
# Scores: (min: 10, avg: 103.36, max: 500)
#
# Run: 1630, exploration: 0.15, score: 39
# Scores: (min: 10, avg: 102.42, max: 500)
#
# Run: 1631, exploration: 0.15, score: 19
# Scores: (min: 10, avg: 102.13, max: 500)
#
# Run: 1632, exploration: 0.15, score: 28
# Scores: (min: 10, avg: 101.76, max: 500)
#
# Run: 1633, exploration: 0.15, score: 16
# Scores: (min: 10, avg: 100.98, max: 500)
#
# Run: 1634, exploration: 0.15, score: 254
# Scores: (min: 10, avg: 103.33, max: 500)
#
# Run: 1635, exploration: 0.15, score: 145
# Scores: (min: 10, avg: 103.9, max: 500)
#
# Run: 1636, exploration: 0.15, score: 123
# Scores: (min: 10, avg: 104.72, max: 500)
#
# Run: 1637, exploration: 0.15, score: 17
# Scores: (min: 10, avg: 104.16, max: 500)
#
# Run: 1638, exploration: 0.15, score: 49
# Scores: (min: 10, avg: 104.38, max: 500)
#
# Run: 1639, exploration: 0.15, score: 69
# Scores: (min: 10, avg: 104.23, max: 500)
#
# Run: 1640, exploration: 0.15, score: 311
# Scores: (min: 10, avg: 106.46, max: 500)
#
# Run: 1641, exploration: 0.15, score: 87
# Scores: (min: 10, avg: 106.87, max: 500)
#
# Run: 1642, exploration: 0.15, score: 40
# Scores: (min: 10, avg: 107.05, max: 500)
#
# Run: 1643, exploration: 0.15, score: 173
# Scores: (min: 10, avg: 107.71, max: 500)
#
# Run: 1644, exploration: 0.15, score: 314
# Scores: (min: 10, avg: 109.69, max: 500)
#
# Run: 1645, exploration: 0.15, score: 39
# Scores: (min: 10, avg: 109.73, max: 500)
#
# Run: 1646, exploration: 0.15, score: 89
# Scores: (min: 10, avg: 108, max: 500)
#
# Run: 1647, exploration: 0.15, score: 181
# Scores: (min: 10, avg: 109.08, max: 500)
#
# Run: 1648, exploration: 0.15, score: 40
# Scores: (min: 10, avg: 108.41, max: 500)
#
# Run: 1649, exploration: 0.15, score: 48
# Scores: (min: 11, avg: 108.79, max: 500)
#
# Run: 1650, exploration: 0.15, score: 220
# Scores: (min: 11, avg: 109.92, max: 500)
#
# Run: 1651, exploration: 0.15, score: 82
# Scores: (min: 11, avg: 110.3, max: 500)
#
# Run: 1652, exploration: 0.15, score: 130
# Scores: (min: 11, avg: 111.41, max: 500)
#
# Run: 1653, exploration: 0.15, score: 30
# Scores: (min: 11, avg: 110.74, max: 500)
#
# Run: 1654, exploration: 0.15, score: 143
# Scores: (min: 11, avg: 111.47, max: 500)
#
# Run: 1655, exploration: 0.15, score: 45
# Scores: (min: 11, avg: 108.49, max: 500)
#
# Run: 1656, exploration: 0.15, score: 166
# Scores: (min: 11, avg: 108.25, max: 500)
#
# Run: 1657, exploration: 0.15, score: 119
# Scores: (min: 11, avg: 108.85, max: 500)
#
# Run: 1658, exploration: 0.15, score: 76
# Scores: (min: 11, avg: 109.16, max: 500)
#
# Run: 1659, exploration: 0.15, score: 63
# Scores: (min: 11, avg: 109.17, max: 500)
#
# Run: 1660, exploration: 0.15, score: 158
# Scores: (min: 11, avg: 110.54, max: 500)
#
# Run: 1661, exploration: 0.15, score: 97
# Scores: (min: 11, avg: 110.6, max: 500)
#
# Run: 1662, exploration: 0.15, score: 127
# Scores: (min: 11, avg: 108.79, max: 500)
#
# Run: 1663, exploration: 0.15, score: 53
# Scores: (min: 11, avg: 107.9, max: 500)
#
# Run: 1664, exploration: 0.15, score: 52
# Scores: (min: 11, avg: 106.76, max: 500)
#
# Run: 1665, exploration: 0.15, score: 14
# Scores: (min: 11, avg: 105.86, max: 500)
#
# Run: 1666, exploration: 0.15, score: 10
# Scores: (min: 10, avg: 104.39, max: 500)
#
# Run: 1667, exploration: 0.15, score: 21
# Scores: (min: 10, avg: 103.57, max: 500)
#
# Run: 1668, exploration: 0.15, score: 21
# Scores: (min: 10, avg: 100.49, max: 500)
#
# Run: 1669, exploration: 0.15, score: 45
# Scores: (min: 10, avg: 100.37, max: 500)
#
# Run: 1670, exploration: 0.15, score: 136
# Scores: (min: 10, avg: 100.43, max: 500)
#
# Run: 1671, exploration: 0.15, score: 74
# Scores: (min: 10, avg: 100.23, max: 500)
#
# Run: 1672, exploration: 0.15, score: 129
# Scores: (min: 10, avg: 96.52, max: 372)
#
# Run: 1673, exploration: 0.15, score: 113
# Scores: (min: 10, avg: 96.61, max: 372)
#
# Run: 1674, exploration: 0.15, score: 33
# Scores: (min: 10, avg: 93.92, max: 372)
#
# Run: 1675, exploration: 0.15, score: 37
# Scores: (min: 10, avg: 94.03, max: 372)
#
# Run: 1676, exploration: 0.15, score: 44
# Scores: (min: 10, avg: 93.56, max: 372)
#
# Run: 1677, exploration: 0.15, score: 23
# Scores: (min: 10, avg: 93.66, max: 372)
#
# Run: 1678, exploration: 0.15, score: 109
# Scores: (min: 10, avg: 93.81, max: 372)
#
# Run: 1679, exploration: 0.15, score: 58
# Scores: (min: 10, avg: 93.09, max: 372)
#
# Run: 1680, exploration: 0.15, score: 23
# Scores: (min: 10, avg: 92.34, max: 372)
#
# Run: 1681, exploration: 0.15, score: 20
# Scores: (min: 10, avg: 92.27, max: 372)
#
# Run: 1682, exploration: 0.15, score: 500
# Scores: (min: 10, avg: 96.21, max: 500)
#
# Run: 1683, exploration: 0.15, score: 101
# Scores: (min: 10, avg: 95.85, max: 500)
#
# Run: 1684, exploration: 0.15, score: 464
# Scores: (min: 10, avg: 99.3, max: 500)
#
# Run: 1685, exploration: 0.15, score: 140
# Scores: (min: 10, avg: 100.42, max: 500)
#
# Run: 1686, exploration: 0.15, score: 56
# Scores: (min: 10, avg: 100.83, max: 500)
#
# Run: 1687, exploration: 0.15, score: 43
# Scores: (min: 10, avg: 101, max: 500)
#
# Run: 1688, exploration: 0.15, score: 182
# Scores: (min: 10, avg: 100.69, max: 500)
#
# Run: 1689, exploration: 0.15, score: 126
# Scores: (min: 10, avg: 101.06, max: 500)
#
# Run: 1690, exploration: 0.15, score: 92
# Scores: (min: 10, avg: 101.02, max: 500)
#
# Run: 1691, exploration: 0.15, score: 239
# Scores: (min: 10, avg: 102.53, max: 500)
#
# Run: 1692, exploration: 0.15, score: 179
# Scores: (min: 10, avg: 104.2, max: 500)
#
# Run: 1693, exploration: 0.15, score: 46
# Scores: (min: 10, avg: 103.76, max: 500)
#
# Run: 1694, exploration: 0.15, score: 46
# Scores: (min: 10, avg: 104.07, max: 500)
#
# Run: 1695, exploration: 0.15, score: 49
# Scores: (min: 10, avg: 103.75, max: 500)
#
# Run: 1696, exploration: 0.15, score: 65
# Scores: (min: 10, avg: 100.68, max: 500)
#
# Run: 1697, exploration: 0.15, score: 178
# Scores: (min: 10, avg: 101.89, max: 500)
#
# Run: 1698, exploration: 0.15, score: 90
# Scores: (min: 10, avg: 101.17, max: 500)
#
# Run: 1699, exploration: 0.15, score: 106
# Scores: (min: 10, avg: 100.58, max: 500)
#
# Run: 1700, exploration: 0.15, score: 186
# Scores: (min: 10, avg: 101.51, max: 500)
#
# Run: 1701, exploration: 0.15, score: 140
# Scores: (min: 10, avg: 102.08, max: 500)
#
# Run: 1702, exploration: 0.15, score: 62
# Scores: (min: 10, avg: 101.1, max: 500)
#
# Run: 1703, exploration: 0.15, score: 334
# Scores: (min: 10, avg: 104.33, max: 500)
#
# Run: 1704, exploration: 0.15, score: 125
# Scores: (min: 10, avg: 105.4, max: 500)
#
# Run: 1705, exploration: 0.15, score: 88
# Scores: (min: 10, avg: 104.73, max: 500)
#
# Run: 1706, exploration: 0.15, score: 116
# Scores: (min: 10, avg: 105.51, max: 500)
#
# Run: 1707, exploration: 0.15, score: 98
# Scores: (min: 10, avg: 106.23, max: 500)
#
# Run: 1708, exploration: 0.15, score: 27
# Scores: (min: 10, avg: 106.33, max: 500)
#
# Run: 1709, exploration: 0.15, score: 26
# Scores: (min: 10, avg: 104.94, max: 500)
#
# Run: 1710, exploration: 0.15, score: 20
# Scores: (min: 10, avg: 104.04, max: 500)
# Run: 1711, exploration: 0.15, score: 23
# Scores: (min: 10, avg: 103.75, max: 500)
#
# Run: 1712, exploration: 0.15, score: 121
# Scores: (min: 10, avg: 104.41, max: 500)
#
# Run: 1713, exploration: 0.15, score: 124
# Scores: (min: 10, avg: 105.18, max: 500)
#
# Run: 1714, exploration: 0.15, score: 165
# Scores: (min: 10, avg: 106.1, max: 500)
#
# Run: 1715, exploration: 0.15, score: 17
# Scores: (min: 10, avg: 105.98, max: 500)
#
# Run: 1716, exploration: 0.15, score: 108
# Scores: (min: 10, avg: 106.69, max: 500)
#
# Run: 1717, exploration: 0.15, score: 113
# Scores: (min: 10, avg: 107.69, max: 500)
#
# Run: 1718, exploration: 0.15, score: 114
# Scores: (min: 10, avg: 107.21, max: 500)
#
# Run: 1719, exploration: 0.15, score: 76
# Scores: (min: 10, avg: 106.58, max: 500)
#
# Run: 1720, exploration: 0.15, score: 55
# Scores: (min: 10, avg: 106.25, max: 500)
#
# Run: 1721, exploration: 0.15, score: 194
# Scores: (min: 10, avg: 106.91, max: 500)

# %% [markdown]
# # Explain how reinforcement learning concepts apply to the cartpole problem.
#
# ### What is the goal of the agent in this case?
#
# The agent's objective is to maintain the pole's state of balance by regulating the cart's movement. Also, reward or penalty points are given to the agent based on how effectively it keeps the pole erect as feedback.
#
# ### What are the various state values?
#
# The various state values of the cart pole include the cartpole's position, the cart's speed or velocity, and the pole's angle represents the pole's direction with respect to the vertical axis. The cart swings from right to left at a certain speed. The motion of the cart creates many states in this experiment. There is an initial position where the cart moves right to left and a final position where the pole falls too fast in one direction.
#
# ### What are the possible actions that can be performed?
#
# There are two possible actions the cart can perform. To maintain the pole balanced and centered, the cart must either go left or right. Otherwise, it will cause the pole to fall or topple.
#
# ### What reinforcement algorithm is used for this problem?
# Deep Q-learning is the learning algorithm that was used to teach the agent how to maneuver the cart to maintain the pole's balance. Q-learning is a model-free reinforcement learning algorithm that learns the value of an action in the various states of the cart. Q-learning builds a Q-table to store values for each state-action pair, enabling the agent to choose the most rewarding actions.
#
# # Analyze how experience replay is applied to the cartpole problem.
#
# ### How does experience replay work in this algorithm?
#
# To enhance learning efficiency and stability, experience replay is commonly used in reinforcement learning algorithms, particularly in Deep Q Networks (DQN). The Q-values are assessments of the effectiveness of any given move the cart makes. Also, the optimum course of action for a specific problem can be found by modifying the Q-values using various right or left adjustments, as I did in the last three experiments.
# Experience replay works by interacting with the environment, while the agent collects experiences such as tuples of state, action, reward, next state, and done flag as it takes actions and observes the outcomes. These experiences are stored in a replay buffer, a fixed-size memory that holds a collection of recent experiences. The learning process uses these sampled events to update the weights of the Q-network, which assists in breaking the temporal connections in the data and improves the reliability and efficiency of training
#
# ### What is the effect of introducing a discount factor for calculating the future rewards?
#
# The discount factor in reinforcement learning is a value between 0 and 1 that determines the present value of future rewards. Its introduction influences the agent's decision-making by providing a mechanism to balance immediate rewards against future rewards. The original discount factor in imported code was 1.0. During the modification experiment, I changed it to 0.80 and I had different results. Short-term gains, such as maintaining the pole's balance for a brief period of time, yield more immediate rewards. Since there is a potential that an action won't provide a reward, those with higher risk have a discounted return for the agent.
#
# # Analyze how neural networks are used in deep Q-learning.
#
# ### Explain the neural network architecture that is used in the cartpole problem.
#
# The neural network architecture used in DQN for the cartpole problem typically involves the Input Layer, the Output Layer, and the Hidden Layer. The inputs of the neural network are formed as states, and the outputs are created as actions with q-values associated with them. The optimal action currently known for that state is represented by the output with the largest Q-value. The state is fed into the neural network, which then generates Q-values for every possible action the agent can take in that state. The next action chosen by the agent is the one with the highest Q-value.
#
# ### How does the neural network make the Q-learning algorithm more efficient?
#
# One of the neural network's advantages which makes it more efficient is that it requires less memory for large or continuous collections. Neural networks allow the agent to estimate Q-values and approximate the Q-function by applying previously learned experiences to new state-action pairs. Neural networks can effectively manage the complexity of issues such as cartpole, which include high-dimensional, continuous state spaces. They are capable of detecting patterns and relationships in the data.
#
# ### What difference do you see in the algorithm performance when you increase or decrease the learning rate?
#
# My initial learning rate of the given code was 0.001. I changed it to 0.01 and I had a different output. It took serveral minutes to complete. I have realized that an increase in the learning rate led to faster convergence as the agent adapts more rapidly to new information. However, a very high learning rate might cause instability, leading to oscillations or overshooting optimal values, hindering convergence.
# Also, when the learning rate decreases, the learning rate makes learning more gradual and stable, potentially ensuring convergence to a better solution over time. To sum up, I would say that the stability and rate of learning are impacted by changing the learning rate in the Deep Q Networks solution for the cartpole problem. It's critical to choose the ideal learning rate because too high might cause instability and too low can hinder reaching a steady state.
#
# # References
#
# Phy, V. (2021, December 12). Reinforcement Learning Concept on Cart-Pole with DQN. Medium. https://towardsdatascience.com/reinforcement-learning-concept-on-cart-pole-with-dqn-799105ca670
#
# Surma, G. (2021, October 13). Cartpole - Introduction to Reinforcement Learning (DQN - Deep Q-Learning). Medium. https://gsurma.medium.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288
#
# Reinforcement Learning (DQN) Tutorial — PyTorch Tutorials 2.1.1+cu121 documentation. (n.d.). https://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html
#
# What is “experience replay” and what are its benefits? (n.d.). Data Science Stack Exchange. https://datascience.stackexchange.com/questions/20535/what-is-experience-replay-and-what-are-its-benefits
#
# Beysolow, I. T. (2019). Applied reinforcement learning with python: With openai gym, tensorflow, and keras. Apress L. P..
# Singh, S. (2022, October 7). How are neural networks used in deep Q-Learning? https://www.turing.com/kb/how-are-neural-networks-used-in-deep-q-learning
#
# Amine, A. (2021, December 24). Deep Q-Networks: from theory to implementation - Towards Data Science. Medium. https://towardsdatascience.com/deep-q-networks-theory-and-implementation-37543f60dd67
